# %%
import pandas as pd
import datetime as dt
import numpy as np
import investpy

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Load data
df = pd.read_csv('xrp.csv')
print(df)
# Out:
#            Date     Open     High      Low    Close      Volume Currency
# 0    2020-06-01  0.20254  0.21184  0.20132  0.21090  1662996864      USD
# 1    2020-06-02  0.21090  0.21452  0.19826  0.20317  2046863744      USD
# 2    2020-06-03  0.20316  0.20475  0.20104  0.20411  1226735360      USD
# 3    2020-06-04  0.20411  0.20713  0.20121  0.20438  1357705728      USD
# 4    2020-06-05  0.20438  0.20567  0.20174  0.20282  1165720704      USD
# ..          ...      ...      ...      ...      ...         ...      ...
# 726  2022-05-28  0.38155  0.38868  0.38068  0.38637   333918176      USD
# 727  2022-05-29  0.38631  0.39004  0.37945  0.38910   279300928      USD
# 728  2022-05-30  0.38910  0.41955  0.38699  0.41859   552421952      USD
# 729  2022-05-31  0.41861  0.43342  0.40694  0.42156   634001152      USD
# 730  2022-06-01  0.42162  0.42625  0.38985  0.39802   671546560      USD
#
# [731 rows x 7 columns]

# %%
# Process data
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv("xrp_processed_7_3.csv")
df
# Out:
#            Date     Open     High      Low    Close      Volume Currency  \
# 20   2020-06-21  0.18793  0.18840  0.18577  0.18606   623938624      USD
# 21   2020-06-22  0.18606  0.19018  0.18584  0.18941  1066312000      USD
# 22   2020-06-23  0.18942  0.19042  0.18839  0.18886   793852224      USD
# 23   2020-06-24  0.18886  0.19010  0.18179  0.18351  1010395648      USD
# 24   2020-06-25  0.18352  0.18406  0.17897  0.18155   912398528      USD
# ..          ...      ...      ...      ...      ...         ...      ...
# 726  2022-05-28  0.38155  0.38868  0.38068  0.38637   333918176      USD
# 727  2022-05-29  0.38631  0.39004  0.37945  0.38910   279300928      USD
# 728  2022-05-30  0.38910  0.41955  0.38699  0.41859   552421952      USD
# 729  2022-05-31  0.41861  0.43342  0.40694  0.42156   634001152      USD
# 730  2022-06-01  0.42162  0.42625  0.38985  0.39802   671546560      USD
#
#          H-L      O-C     SMA_7    SMA_14    SMA_21      SD_7     SD_21
# 20   0.00263  0.00187  0.189860  0.192946  0.196841  0.002852  0.007476
# 21   0.00434 -0.00335  0.189431  0.191899  0.195818  0.002621  0.006904
# 22   0.00203  0.00056  0.188927  0.191008  0.195137  0.002273  0.006848
# 23   0.00831  0.00535  0.187546  0.189637  0.194156  0.002195  0.006973
# 24   0.00509  0.00197  0.186370  0.189149  0.193069  0.002892  0.007078
# ..       ...      ...       ...       ...       ...       ...       ...
# 726  0.00800 -0.00482  0.400311  0.411512  0.427511  0.014112  0.044784
# 727  0.01059 -0.00279  0.395640  0.407309  0.419078  0.010848  0.032297
# 728  0.03256 -0.02949  0.397569  0.406996  0.415789  0.013647  0.028223
# 729  0.02648 -0.00295  0.399423  0.405830  0.411425  0.016061  0.017426
# 730  0.03640  0.02360  0.398254  0.405315  0.410583  0.015781  0.017635
#
# [711 rows x 14 columns]

# %%
pre_day = 30
scala_x = MinMaxScaler(feature_range=(0,1))
scala_y = MinMaxScaler(feature_range=(0,1))
cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))

x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])

test_size = (int)(len(scaled_data_y) * 0.3)
print(test_size)

x_train = np.array(x_total[:len(x_total)-test_size])
x_test = np.array(x_total[len(x_total)-test_size:])
y_train = np.array(y_total[:len(y_total)-test_size])
y_test = np.array(y_total[len(y_total)-test_size:])



print(x_train.shape, y_train.shape, x_test.shape, y_test.shape)
# Out:
# 213
# (468, 30, 7) (468, 1) (213, 30, 7) (213, 1)

# %%
# Build model
model = Sequential()

model.add(LSTM(units=60, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=60, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_train, y_train, epochs=120, steps_per_epoch=40, use_multiprocessing=True)
model.save("xrp_lstm_7_3.h5")
# Out:
# Epoch 1/120
# 40/40 [==============================] - 9s 49ms/step - loss: 0.0375
# Epoch 2/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0192
# Epoch 3/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0209
# Epoch 4/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0157
# Epoch 5/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0141
# Epoch 6/120
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0107
# Epoch 7/120
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0114
# Epoch 8/120
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0107
# Epoch 9/120
# 40/40 [==============================] - 3s 64ms/step - loss: 0.0080
# Epoch 10/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0098
# Epoch 11/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0072
# Epoch 12/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0068
# Epoch 13/120
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0069
# Epoch 14/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0080
# Epoch 15/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0068
# Epoch 16/120
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0068
# Epoch 17/120
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0056
# Epoch 18/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0049
# Epoch 19/120
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0043
# Epoch 20/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0065
# Epoch 21/120
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0043
# Epoch 22/120
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0046
# Epoch 23/120
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0041
# Epoch 24/120
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0045
# Epoch 25/120
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0044
# Epoch 26/120
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0047
# Epoch 27/120
# 40/40 [==============================] - 3s 72ms/step - loss: 0.0042
# Epoch 28/120
# 40/40 [==============================] - 3s 70ms/step - loss: 0.0047
# Epoch 29/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0039
# Epoch 30/120
# 40/40 [==============================] - 3s 72ms/step - loss: 0.0045
# Epoch 31/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0045
# Epoch 32/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0035
# Epoch 33/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0038
# Epoch 34/120
# 40/40 [==============================] - 3s 70ms/step - loss: 0.0040
# Epoch 35/120
# 40/40 [==============================] - 3s 71ms/step - loss: 0.0036
# Epoch 36/120
# 40/40 [==============================] - 3s 72ms/step - loss: 0.0038
# Epoch 37/120
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0034
# Epoch 38/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0034
# Epoch 39/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0033
# Epoch 40/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0035
# Epoch 41/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0033
# Epoch 42/120
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0032
# Epoch 43/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0036
# Epoch 44/120
# 40/40 [==============================] - 2s 55ms/step - loss: 0.0031
# Epoch 45/120
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0031
# Epoch 46/120
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0036
# Epoch 47/120
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0032
# Epoch 48/120
# 40/40 [==============================] - 2s 63ms/step - loss: 0.0039
# Epoch 49/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0038
# Epoch 50/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0030
# Epoch 51/120
# 40/40 [==============================] - 3s 66ms/step - loss: 0.0028
# Epoch 52/120
# 40/40 [==============================] - 3s 64ms/step - loss: 0.0036
# Epoch 53/120
# 40/40 [==============================] - 3s 63ms/step - loss: 0.0029
# Epoch 54/120
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0036
# Epoch 55/120
# 40/40 [==============================] - 3s 65ms/step - loss: 0.0028
# Epoch 56/120
# 40/40 [==============================] - 3s 66ms/step - loss: 0.0027
# Epoch 57/120
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0030
# Epoch 58/120
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0028
# Epoch 59/120
# 40/40 [==============================] - 3s 67ms/step - loss: 0.0031
# Epoch 60/120
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0027
# Epoch 61/120
# 40/40 [==============================] - 3s 70ms/step - loss: 0.0025
# Epoch 62/120
# 40/40 [==============================] - 3s 71ms/step - loss: 0.0035
# Epoch 63/120
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0030
# Epoch 64/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0029
# Epoch 65/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0027
# Epoch 66/120
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0028
# Epoch 67/120
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0023
# Epoch 68/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0026
# Epoch 69/120
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0028
# Epoch 70/120
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0026
# Epoch 71/120
# 40/40 [==============================] - 3s 85ms/step - loss: 0.0028
# Epoch 72/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0026
# Epoch 73/120
# 40/40 [==============================] - 3s 86ms/step - loss: 0.0027
# Epoch 74/120
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0024
# Epoch 75/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0031
# Epoch 76/120
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0028
# Epoch 77/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0025
# Epoch 78/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0025
# Epoch 79/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0024
# Epoch 80/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0027
# Epoch 81/120
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0024
# Epoch 82/120
# 40/40 [==============================] - 3s 76ms/step - loss: 0.0023
# Epoch 83/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0026
# Epoch 84/120
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0029
# Epoch 85/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0027
# Epoch 86/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0030
# Epoch 87/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0027
# Epoch 88/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0027
# Epoch 89/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0029
# Epoch 90/120
# 40/40 [==============================] - 4s 89ms/step - loss: 0.0021
# Epoch 91/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0023
# Epoch 92/120
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0027
# Epoch 93/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0025
# Epoch 94/120
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0025
# Epoch 95/120
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0028
# Epoch 96/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0020
# Epoch 97/120
# 40/40 [==============================] - 3s 72ms/step - loss: 0.0023
# Epoch 98/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0023
# Epoch 99/120
# 40/40 [==============================] - 3s 78ms/step - loss: 0.0023
# Epoch 100/120
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0024
# Epoch 101/120
# 40/40 [==============================] - 3s 86ms/step - loss: 0.0027
# Epoch 102/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0025
# Epoch 103/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0026
# Epoch 104/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0021
# Epoch 105/120
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0023
# Epoch 106/120
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0024
# Epoch 107/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0020
# Epoch 108/120
# 40/40 [==============================] - 3s 82ms/step - loss: 0.0025
# Epoch 109/120
# 40/40 [==============================] - 3s 84ms/step - loss: 0.0023
# Epoch 110/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0016
# Epoch 111/120
# 40/40 [==============================] - 3s 80ms/step - loss: 0.0017
# Epoch 112/120
# 40/40 [==============================] - 3s 87ms/step - loss: 0.0024
# Epoch 113/120
# 40/40 [==============================] - 3s 81ms/step - loss: 0.0022
# Epoch 114/120
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0023
# Epoch 115/120
# 40/40 [==============================] - 3s 83ms/step - loss: 0.0024
# Epoch 116/120
# 40/40 [==============================] - 3s 77ms/step - loss: 0.0018
# Epoch 117/120
# 40/40 [==============================] - 3s 79ms/step - loss: 0.0021
# Epoch 118/120
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 4800 batches). You may need to use the repeat() function when building your dataset.
# 40/40 [==============================] - 2s 49ms/step - loss: 0.0021

# %%
# Testing
predict_price = model.predict(x_test)
predict_price = scala_y.inverse_transform(predict_price)
# Out:
# 7/7 [==============================] - 3s 31ms/step

# %%
# Ploting the stat
real_price = df[len(df)-test_size:]['Close'].values.reshape(-1,1)
real_price = np.array(real_price)
print(real_price.shape)
real_price = real_price.reshape(real_price.shape[0], 1)

plt.figure(figsize=(20,10))
plt.plot(real_price, color="red", label="Real XRP Prices")
plt.plot(predict_price, color="blue", label="Predicted XRP Prices")
plt.title("XRP Prices")
plt.xlabel("Time (day)")
plt.ylabel("Stock Prices")
plt.ylim(bottom=0)
plt.legend()
plt.show()
# Out:
# (213, 1)

# %%
# Make Prediction
x_predict = df[len(df)-pre_day:][cols_x].values.reshape(-1, len(cols_x))
x_predict = scala_x.transform(x_predict)
x_predict = np.array(x_predict)
x_predict = x_predict.reshape(1, x_predict.shape[0], len(cols_x))

prediction = model.predict(x_predict)
prediction = scala_y.inverse_transform(prediction)
print(prediction)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# [[0.37805995]]

# %%
mae = mean_absolute_error(real_price, predict_price)
mape = mean_absolute_percentage_error(real_price, predict_price)
mse = mean_squared_error(real_price, predict_price)
rmse = np.sqrt(mse)
r2 = r2_score(real_price, predict_price)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 0.12
# MAPE: 17.06%
# MSE: 0.02
# RMSE: 0.14
# R2: 0.48
