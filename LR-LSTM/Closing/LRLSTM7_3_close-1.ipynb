# %% [markdown]
# # 1. Quá trình dự báo trên mô hình LR

# %% [markdown]
# ## Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from statsmodels.tsa.stattools import adfuller


from sklearn.metrics import mean_squared_error
from sklearn.utils import column_or_1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model

# %% [markdown]
# ## Nạp dữ liệu từ file csv

# %%
df = pd.read_csv('btc.csv', parse_dates=True,
                 index_col=0).drop(columns=['Open', 'High', 'Low', 'Volume', 'Currency'])
df
# Out:
#               Close
# Date
# 2020-06-01  1.01893
# 2020-06-02  0.95276
# 2020-06-03  0.96672
# 2020-06-04  0.97944
# 2020-06-05  0.96312
# ...             ...
# 2022-05-28  2.90271
# 2022-05-29  2.94652
# 2022-05-30  3.17233
# 2022-05-31  3.17934
# 2022-06-01  2.97985
#
# [731 rows x 1 columns]

# %%
df['Timestamp'] = pd.to_datetime(df.index).astype(np.int64) / 10**9
df_index = df.index
df_close = df['Close'].values.reshape(-1, 1)
df.head()

df
# Out:
#               Close     Timestamp
# Date
# 2020-06-01  1.01893  1.590970e+09
# 2020-06-02  0.95276  1.591056e+09
# 2020-06-03  0.96672  1.591142e+09
# 2020-06-04  0.97944  1.591229e+09
# 2020-06-05  0.96312  1.591315e+09
# ...             ...           ...
# 2022-05-28  2.90271  1.653696e+09
# 2022-05-29  2.94652  1.653782e+09
# 2022-05-30  3.17233  1.653869e+09
# 2022-05-31  3.17934  1.653955e+09
# 2022-06-01  2.97985  1.654042e+09
#
# [731 rows x 2 columns]

# %% [markdown]
# ## Chuẩn hóa dữ liệu

# %%
LR_sc = StandardScaler()

df_scaled = df.copy()
df_scaled['Close'] = LR_sc.fit_transform(df_close)
df_scaled
# Out:
#                Close     Timestamp
# Date
# 2020-06-01 -1.526877  1.590970e+09
# 2020-06-02 -1.566503  1.591056e+09
# 2020-06-03 -1.558143  1.591142e+09
# 2020-06-04 -1.550526  1.591229e+09
# 2020-06-05 -1.560299  1.591315e+09
# ...              ...           ...
# 2022-05-28 -0.398775  1.653696e+09
# 2022-05-29 -0.372539  1.653782e+09
# 2022-05-30 -0.237313  1.653869e+09
# 2022-05-31 -0.233115  1.653955e+09
# 2022-06-01 -0.352580  1.654042e+09
#
# [731 rows x 2 columns]

# %% [markdown]
# ## Vẽ đồ thị

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Bitcoin Price'
ylabel = 'USD'
xlabel = 'Date'

ax = df['Close'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
df
# Out:
#               Close     Timestamp
# Date
# 2020-06-01  1.01893  1.590970e+09
# 2020-06-02  0.95276  1.591056e+09
# 2020-06-03  0.96672  1.591142e+09
# 2020-06-04  0.97944  1.591229e+09
# 2020-06-05  0.96312  1.591315e+09
# ...             ...           ...
# 2022-05-28  2.90271  1.653696e+09
# 2022-05-29  2.94652  1.653782e+09
# 2022-05-30  3.17233  1.653869e+09
# 2022-05-31  3.17934  1.653955e+09
# 2022-06-01  2.97985  1.654042e+09
#
# [731 rows x 2 columns]

# %% [markdown]
# ## Chuẩn hóa dữ liệu

# %%
X_sc = StandardScaler()
y_sc = StandardScaler()

X = df.iloc[:, 1].values.reshape(-1, 1)
y = df.iloc[:, 0].values.reshape(-1, 1)


X_scaled = X_sc.fit_transform(X)
y_scaled = y_sc.fit_transform(y)


df_scaled = pd.DataFrame(index=df_index)
df_scaled['Timestamp'] = X_scaled
df_scaled['Close'] = y_scaled
df_scaled.head()
# Out:
#             Timestamp     Close
# Date
# 2020-06-01  -1.729683 -1.526877
# 2020-06-02  -1.724944 -1.566503
# 2020-06-03  -1.720205 -1.558143
# 2020-06-04  -1.715466 -1.550526
# 2020-06-05  -1.710728 -1.560299

# %% [markdown]
# ## Chia tập dữ liệu

# %%
interrupt = int(len(df_scaled) * .7)
interrupt
# Out:
# 511

# %%
train_data, test_data = df_scaled[:interrupt], df_scaled[interrupt:]
index_test = df_scaled.index[interrupt:]
print(train_data.shape)
print(test_data.shape)
# Out:
# (511, 2)
# (220, 2)

# %%
train_data.tail()
# Out:
#             Timestamp     Close
# Date
# 2021-10-20   0.668179  1.814097
# 2021-10-21   0.672918  1.588396
# 2021-10-22   0.677657  1.497377
# 2021-10-23   0.682395  1.534638
# 2021-10-24   0.687134  1.507929

# %%
test_data.head()
# Out:
#             Timestamp     Close
# Date
# 2021-10-25   0.691873  1.639706
# 2021-10-26   0.696612  1.474651
# 2021-10-27   0.701351  1.362504
# 2021-10-28   0.706090  1.490921
# 2021-10-29   0.710829  1.590349

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.ylabel('Closing Prices')
plt.plot(train_data['Close'], 'blue', label='Train data')
plt.plot(test_data['Close'], 'green', label='Test data')
plt.legend()

# %% [markdown]
# *   Gọi biến X <- Timestamp
# *   Gọi biến y <- Close

# %%
X_train = train_data['Timestamp'].values.reshape(-1, 1)
y_train = train_data['Close'].values.reshape(-1, 1)

X_test = test_data['Timestamp'].values.reshape(-1, 1)
y_test = test_data['Close'].values.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
LR_model = LinearRegression()
LR_model.fit(X_train,y_train)
pred = LR_model.predict(X_test)

# %%
inv_pred = y_sc.inverse_transform(pred.reshape(-1, 1))
inv_test = y_sc.inverse_transform(y_test.reshape(-1, 1))

# %% [markdown]
# ## Vẽ đồ thị cho tập test và kết quả dự đoán

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.ylabel('Closing Prices')
plt.plot(column_or_1d(inv_test), 'blue', label='Actual data')
plt.plot(column_or_1d(inv_pred), 'orange', label='Predicted data')
plt.legend()

# %%
from sklearn.metrics import r2_score
mae = mean_absolute_error(inv_test, inv_pred)
mape = mean_absolute_percentage_error(inv_test, inv_pred)
mse = mean_squared_error(inv_test, inv_pred)
rmse = np.sqrt(mse)
r2 = r2_score(inv_test, inv_pred)
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape*100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 2.48
# MAPE: 64.72%
# MSE: 7.99
# RMSE: 2.83
# R2: -8.25

# %% [markdown]
# ## Tạo một DataFrame là 'df_pred' để lưu kết quả dự đoán trên mô hình LR

# %%
df_pred = pd.DataFrame(columns=['Actual', 'Pred', 'Error'], index=index_test)
df_pred['Actual'] = column_or_1d(inv_test)
df_pred['Pred'] = column_or_1d(inv_pred)
df_pred['Error'] = df_pred['Actual'] - df_pred['Pred']
df_pred
# Out:
#              Actual      Pred     Error
# Date
# 2021-10-25  6.30670  5.736749  0.569951
# 2021-10-26  6.03108  5.746667  0.284413
# 2021-10-27  5.84381  5.756585  0.087225
# 2021-10-28  6.05825  5.766503  0.291747
# 2021-10-29  6.22428  5.776421  0.447859
# ...             ...       ...       ...
# 2022-05-28  2.90271  7.869147 -4.966437
# 2022-05-29  2.94652  7.879065 -4.932545
# 2022-05-30  3.17233  7.888983 -4.716653
# 2022-05-31  3.17934  7.898902 -4.719562
# 2022-06-01  2.97985  7.908820 -4.928970
#
# [220 rows x 3 columns]

# %% [markdown]
# # 2. Quá trình dự đoán trên mô hình LSTM

# %% [markdown]
# ## Tạo thêm một DataFrame để tiến hành dự đoán sai số trên mô hình LSTM

# %%
df_lstm = df_pred.copy()
df_lstm
# Out:
#              Actual      Pred     Error
# Date
# 2021-10-25  6.30670  5.736749  0.569951
# 2021-10-26  6.03108  5.746667  0.284413
# 2021-10-27  5.84381  5.756585  0.087225
# 2021-10-28  6.05825  5.766503  0.291747
# 2021-10-29  6.22428  5.776421  0.447859
# ...             ...       ...       ...
# 2022-05-28  2.90271  7.869147 -4.966437
# 2022-05-29  2.94652  7.879065 -4.932545
# 2022-05-30  3.17233  7.888983 -4.716653
# 2022-05-31  3.17934  7.898902 -4.719562
# 2022-06-01  2.97985  7.908820 -4.928970
#
# [220 rows x 3 columns]

# %% [markdown]
# ## Vẽ đồ thị thể hiện sai số

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

error = df_lstm[['Error']]
title = 'Residual from LR model'
ylabel = 'USD'
xlabel = 'Date'

ax = error.plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
error = np.array(error)
error
# Out:
# array([[ 0.56995147],
#        [ 0.28441333],
#        [ 0.0872252 ],
#        [ 0.29174707],
#        [ 0.44785893],
#        [ 0.3976708 ],
#        [ 0.33470267],
#        [ 0.28535453],
#        [ 0.5060764 ],
#        [ 0.46583827],
#        [ 0.30533014],
#        [ 0.251582  ],
#        [ 0.29262387],
#        [ 0.46163574],
#        [ 0.8771876 ],
#        [ 0.80491947],
#        [ 0.59782134],
#        [ 0.5753132 ],
#        [ 0.49817507],
#        [ 0.51466694],
#        [ 0.6157088 ],
#        [ 0.41476067],
#        [ 0.05396254],
#        [ 0.0719144 ],
#        [-0.27925373],
#        [-0.17636186],
#        [-0.02286   ],
#        [-0.13310813],
#        [-0.38357626],
#        [-0.2670544 ],
#        [-0.31712253],
#        [-0.15070066],
#        [-0.6810388 ],
#        [-0.58745693],
#        [-0.34481506],
#        [-0.3044032 ],
#        [-0.40551133],
#        [-0.38268946],
#        [-0.4640376 ],
#        [-0.76040573],
#        [-1.21395386],
#        [-1.202842  ],
#        [-1.09710013],
#        [-1.10370826],
#        [-1.1257564 ],
#        [-1.42340453],
#        [-1.47926266],
#        [-1.2714508 ],
#        [-1.20471893],
#        [-1.55237706],
#        [-1.3960052 ],
#        [-1.35542333],
#        [-1.48967146],
#        [-1.64518959],
#        [-1.58670773],
#        [-1.61179586],
#        [-1.60264399],
#        [-1.41188213],
#        [-1.45203026],
#        [-1.24181839],
#        [-1.25322653],
#        [-1.30111466],
#        [-1.27368279],
#        [-1.29377093],
#        [-1.61698906],
#        [-1.73525719],
#        [-1.67901533],
#        [-1.77931346],
#        [-1.63738159],
#        [-1.68991973],
#        [-1.78799786],
#        [-1.85720599],
#        [-2.10826413],
#        [-2.15102226],
#        [-2.31602039],
#        [-2.31340853],
#        [-2.30569666],
#        [-2.31722479],
#        [-2.23704293],
#        [-2.13018106],
#        [-2.27419919],
#        [-2.23278733],
#        [-2.24033546],
#        [-2.25204359],
#        [-2.34894173],
#        [-2.34332986],
#        [-2.42192799],
#        [-2.52803613],
#        [-2.96199426],
#        [-3.11194239],
#        [-3.00243053],
#        [-2.97066866],
#        [-2.95415679],
#        [-2.97909493],
#        [-2.95262306],
#        [-2.90446119],
#        [-2.87180932],
#        [-2.90703746],
#        [-2.85886559],
#        [-2.84767372],
#        [-3.03954186],
#        [-3.00969999],
#        [-2.59163812],
#        [-2.61710626],
#        [-2.52901439],
#        [-2.39476252],
#        [-2.38425066],
#        [-2.35909879],
#        [-2.45580692],
#        [-2.57898506],
#        [-2.60722319],
#        [-2.63155132],
#        [-2.59254946],
#        [-2.40305759],
#        [-2.47905572],
#        [-2.82205386],
#        [-2.88724199],
#        [-2.88814012],
#        [-3.07158826],
#        [-3.21523639],
#        [-3.10210452],
#        [-3.21438266],
#        [-3.11284079],
#        [-3.03571892],
#        [-3.05504706],
#        [-3.20760519],
#        [-2.66761332],
#        [-2.55432146],
#        [-2.61498959],
#        [-2.76988772],
#        [-3.11183586],
#        [-3.09644399],
#        [-3.20563212],
#        [-3.25338026],
#        [-3.19129839],
#        [-2.88279652],
#        [-3.14398466],
#        [-3.22251279],
#        [-3.22402092],
#        [-3.33612905],
#        [-3.15817719],
#        [-3.20663532],
#        [-3.03325345],
#        [-3.06356159],
#        [-2.98817972],
#        [-2.95157785],
#        [-3.05719599],
#        [-3.09251412],
#        [-2.96733225],
#        [-2.92335039],
#        [-2.82316852],
#        [-2.80128665],
#        [-2.78950479],
#        [-2.56832292],
#        [-2.55364105],
#        [-2.52915919],
#        [-2.57647732],
#        [-2.74139545],
#        [-2.67411359],
#        [-2.73263172],
#        [-2.68294985],
#        [-2.67066799],
#        [-2.79288612],
#        [-3.03610425],
#        [-3.01852239],
#        [-3.14574052],
#        [-3.10645865],
#        [-3.17927679],
#        [-3.45329492],
#        [-3.40511305],
#        [-3.30953119],
#        [-3.43914932],
#        [-3.38666745],
#        [-3.41438559],
#        [-3.49220372],
#        [-3.39212185],
#        [-3.33203999],
#        [-3.35545812],
#        [-3.45397625],
#        [-3.54119439],
#        [-3.58021252],
#        [-3.58553065],
#        [-3.49914878],
#        [-3.74046692],
#        [-3.63738505],
#        [-3.59680318],
#        [-3.72342132],
#        [-3.82643945],
#        [-3.75525758],
#        [-3.75987572],
#        [-3.84939385],
#        [-3.66231198],
#        [-3.98663012],
#        [-4.05004825],
#        [-4.11406638],
#        [-4.26478452],
#        [-4.67120265],
#        [-4.58987078],
#        [-4.79371892],
#        [-4.81285705],
#        [-4.79193518],
#        [-4.72225332],
#        [-4.60934145],
#        [-4.76522958],
#        [-4.71629772],
#        [-4.90159585],
#        [-4.74929398],
#        [-4.87194212],
#        [-4.85626025],
#        [-4.78097838],
#        [-4.91022652],
#        [-4.86460465],
#        [-4.88533278],
#        [-4.92896092],
#        [-4.99910905],
#        [-4.96643718],
#        [-4.93254532],
#        [-4.71665345],
#        [-4.71956158],
#        [-4.92896972]])

# %%
look_back = 3
x_total, y_total = [], []
for i in range(look_back, len(error)):
	x_total.append(error[i-look_back:i])
	y_total.append(error[i])
x_train = np.array(x_total[:len(error)])
y_train = np.array(y_total[:len(error)])

print("x_train",x_train.shape)
print("y_train",y_train.shape)
# Out:
# x_train (217, 3, 1)
# y_train (217, 1)

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(x_train, y_train, epochs=300, verbose=1)
model.save("bitcoin.h5")
# Out:
# Epoch 1/300
# 7/7 [==============================] - 3s 6ms/step - loss: 7.8433
# Epoch 2/300
# 7/7 [==============================] - 0s 6ms/step - loss: 7.3115
# Epoch 3/300
# 7/7 [==============================] - 0s 7ms/step - loss: 6.6376
# Epoch 4/300
# 7/7 [==============================] - 0s 6ms/step - loss: 5.6463
# Epoch 5/300
# 7/7 [==============================] - 0s 6ms/step - loss: 4.0482
# Epoch 6/300
# 7/7 [==============================] - 0s 6ms/step - loss: 1.7067
# Epoch 7/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.7304
# Epoch 8/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6705
# Epoch 9/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4778
# Epoch 10/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4053
# Epoch 11/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3034
# Epoch 12/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2886
# Epoch 13/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2471
# Epoch 14/300
# 7/7 [==============================] - 0s 12ms/step - loss: 0.2195
# Epoch 15/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1931
# Epoch 16/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1712
# Epoch 17/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1511
# Epoch 18/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1309
# Epoch 19/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1154
# Epoch 20/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1004
# Epoch 21/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0886
# Epoch 22/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0791
# Epoch 23/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0694
# Epoch 24/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0604
# Epoch 25/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0524
# Epoch 26/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0453
# Epoch 27/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0404
# Epoch 28/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0370
# Epoch 29/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0337
# Epoch 30/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0321
# Epoch 31/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0299
# Epoch 32/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0289
# Epoch 33/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0291
# Epoch 34/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0294
# Epoch 35/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0277
# Epoch 36/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0290
# Epoch 37/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0283
# Epoch 38/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0264
# Epoch 39/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0265
# Epoch 40/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0258
# Epoch 41/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0254
# Epoch 42/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0252
# Epoch 43/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0256
# Epoch 44/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0247
# Epoch 45/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0249
# Epoch 46/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0262
# Epoch 47/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0250
# Epoch 48/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 49/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0247
# Epoch 50/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0251
# Epoch 51/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 52/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0250
# Epoch 53/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0243
# Epoch 54/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0248
# Epoch 55/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0242
# Epoch 56/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 57/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 58/300
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0237
# Epoch 59/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0249
# Epoch 60/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0245
# Epoch 61/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0245
# Epoch 62/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0244
# Epoch 63/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0247
# Epoch 64/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0235
# Epoch 65/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237
# Epoch 66/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0260
# Epoch 67/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0256
# Epoch 68/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0263
# Epoch 69/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0249
# Epoch 70/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0233
# Epoch 71/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0240
# Epoch 72/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238
# Epoch 73/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0241
# Epoch 74/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 75/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235
# Epoch 76/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0241
# Epoch 77/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 78/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 79/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0270
# Epoch 80/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0244
# Epoch 81/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0240
# Epoch 82/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0247
# Epoch 83/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236
# Epoch 84/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236
# Epoch 85/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0238
# Epoch 86/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 87/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237
# Epoch 88/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237
# Epoch 89/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0232
# Epoch 90/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0233
# Epoch 91/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0235
# Epoch 92/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235
# Epoch 93/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0231
# Epoch 94/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0232
# Epoch 95/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0234
# Epoch 96/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0228
# Epoch 97/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 98/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0251
# Epoch 99/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0236
# Epoch 100/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 101/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0252
# Epoch 102/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0230
# Epoch 103/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 104/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 105/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0234
# Epoch 106/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0243
# Epoch 107/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0234
# Epoch 108/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 109/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235
# Epoch 110/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0231
# Epoch 111/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 112/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0227
# Epoch 113/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0231
# Epoch 114/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0228
# Epoch 115/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 116/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 117/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0227
# Epoch 118/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0237
# Epoch 119/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 120/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0234
# Epoch 121/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 122/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 123/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0230
# Epoch 124/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0223
# Epoch 125/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0228
# Epoch 126/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0224
# Epoch 127/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 128/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0225
# Epoch 129/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 130/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 131/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0222
# Epoch 132/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0228
# Epoch 133/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0225
# Epoch 134/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0224
# Epoch 135/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0224
# Epoch 136/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0228
# Epoch 137/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 138/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0225
# Epoch 139/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 140/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 141/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 142/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 143/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 144/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0223
# Epoch 145/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 146/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 147/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0240
# Epoch 148/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0248
# Epoch 149/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 150/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0229
# Epoch 151/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0226
# Epoch 152/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0218
# Epoch 153/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 154/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0229
# Epoch 155/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0238
# Epoch 156/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0239
# Epoch 157/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0249
# Epoch 158/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 159/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0218
# Epoch 160/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0224
# Epoch 161/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 162/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 163/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 164/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 165/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 166/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0236
# Epoch 167/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 168/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0230
# Epoch 169/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 170/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 171/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 172/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 173/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0234
# Epoch 174/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0226
# Epoch 175/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0224
# Epoch 176/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 177/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 178/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0228
# Epoch 179/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 180/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 181/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 182/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 183/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 184/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 185/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0222
# Epoch 186/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 187/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0217
# Epoch 188/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 189/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0233
# Epoch 190/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 191/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 192/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 193/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 194/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 195/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 196/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 197/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 198/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 199/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0213
# Epoch 200/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 201/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 202/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 203/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0210
# Epoch 204/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0212
# Epoch 205/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0212
# Epoch 206/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 207/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 208/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0220
# Epoch 209/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 210/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0224
# Epoch 211/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0240
# Epoch 212/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0232
# Epoch 213/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0225
# Epoch 214/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 215/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 216/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 217/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0211
# Epoch 218/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 219/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0231
# Epoch 220/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210
# Epoch 221/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0225
# Epoch 222/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 223/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210
# Epoch 224/300
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0210
# Epoch 225/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 226/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 227/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 228/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 229/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0238
# Epoch 230/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 231/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 232/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0217
# Epoch 233/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210
# Epoch 234/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0211
# Epoch 235/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 236/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 237/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 238/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0228
# Epoch 239/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0210
# Epoch 240/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 241/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 242/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0215
# Epoch 243/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 244/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 245/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0226
# Epoch 246/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 247/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0235
# Epoch 248/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0274
# Epoch 249/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0263
# Epoch 250/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0225
# Epoch 251/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0242
# Epoch 252/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0222
# Epoch 253/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 254/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0223
# Epoch 255/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0237
# Epoch 256/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0210
# Epoch 257/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0219
# Epoch 258/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 259/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0212
# Epoch 260/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 261/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 262/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0224
# Epoch 263/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 264/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0217
# Epoch 265/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0209
# Epoch 266/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 267/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 268/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0221
# Epoch 269/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0213
# Epoch 270/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0236
# Epoch 271/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0248
# Epoch 272/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0216
# Epoch 273/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 274/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0229
# Epoch 275/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0220
# Epoch 276/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0210
# Epoch 277/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 278/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0230
# Epoch 279/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0249
# Epoch 280/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0241
# Epoch 281/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 282/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0219
# Epoch 283/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0221
# Epoch 284/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0249
# Epoch 285/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0227
# Epoch 286/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0246
# Epoch 287/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0208
# Epoch 288/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210
# Epoch 289/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0209
# Epoch 290/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0211
# Epoch 291/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0215
# Epoch 292/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0213
# Epoch 293/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0206
# Epoch 294/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0210
# Epoch 295/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0216
# Epoch 296/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 297/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0214
# Epoch 298/300
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0215
# Epoch 299/300
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0228
# Epoch 300/300
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0237

# %%
model = load_model("bitcoin.h5")
error_pred = model.predict(x_train)
error_pred
# Out:
# array([[ 0.14700767],
#        [ 0.3626253 ],
#        [ 0.43854752],
#        [ 0.37864134],
#        [ 0.35557985],
#        [ 0.32786837],
#        [ 0.53849   ],
#        [ 0.41800192],
#        [ 0.3005967 ],
#        [ 0.3080779 ],
#        [ 0.34603694],
#        [ 0.48683605],
#        [ 0.8045614 ],
#        [ 0.54595846],
#        [ 0.4748936 ],
#        [ 0.5807808 ],
#        [ 0.45290747],
#        [ 0.5087035 ],
#        [ 0.5747302 ],
#        [ 0.32804304],
#        [ 0.06657522],
#        [ 0.15457496],
#        [-0.270718  ],
#        [-0.16530818],
#        [-0.13442066],
#        [-0.19943547],
#        [-0.3876216 ],
#        [-0.33377823],
#        [-0.43227088],
#        [-0.2684716 ],
#        [-0.72490513],
#        [-0.6506674 ],
#        [-0.4668577 ],
#        [-0.41076288],
#        [-0.51149774],
#        [-0.49914542],
#        [-0.5813903 ],
#        [-0.8454838 ],
#        [-1.241989  ],
#        [-1.2636738 ],
#        [-1.191376  ],
#        [-1.2020144 ],
#        [-1.2222499 ],
#        [-1.4813771 ],
#        [-1.5200211 ],
#        [-1.3355589 ],
#        [-1.2908771 ],
#        [-1.6085678 ],
#        [-1.4456971 ],
#        [-1.4288543 ],
#        [-1.5558672 ],
#        [-1.6886398 ],
#        [-1.6389841 ],
#        [-1.6688582 ],
#        [-1.6578501 ],
#        [-1.465329  ],
#        [-1.523805  ],
#        [-1.3082535 ],
#        [-1.3410491 ],
#        [-1.3795615 ],
#        [-1.3511237 ],
#        [-1.3743297 ],
#        [-1.6630077 ],
#        [-1.7645236 ],
#        [-1.7312285 ],
#        [-1.8364574 ],
#        [-1.6872747 ],
#        [-1.7482622 ],
#        [-1.8410212 ],
#        [-1.9111758 ],
#        [-2.149494  ],
#        [-2.2005405 ],
#        [-2.3736782 ],
#        [-2.3778965 ],
#        [-2.37904   ],
#        [-2.3911164 ],
#        [-2.3071148 ],
#        [-2.196269  ],
#        [-2.3472092 ],
#        [-2.2972054 ],
#        [-2.312437  ],
#        [-2.3224342 ],
#        [-2.4183276 ],
#        [-2.413962  ],
#        [-2.4960396 ],
#        [-2.5877855 ],
#        [-2.931329  ],
#        [-3.1074522 ],
#        [-3.0862749 ],
#        [-3.0668864 ],
#        [-3.0441606 ],
#        [-3.0653405 ],
#        [-3.0389135 ],
#        [-2.9946284 ],
#        [-2.9618893 ],
#        [-2.9919431 ],
#        [-2.9437253 ],
#        [-2.936089  ],
#        [-3.0968256 ],
#        [-3.0798435 ],
#        [-2.6422634 ],
#        [-2.715704  ],
#        [-2.6137385 ],
#        [-2.4701703 ],
#        [-2.4652882 ],
#        [-2.435377  ],
#        [-2.5293121 ],
#        [-2.6326473 ],
#        [-2.6729462 ],
#        [-2.7075481 ],
#        [-2.6746686 ],
#        [-2.475131  ],
#        [-2.5683303 ],
#        [-2.8245738 ],
#        [-2.9131687 ],
#        [-2.9669821 ],
#        [-3.1294496 ],
#        [-3.2579706 ],
#        [-3.190006  ],
#        [-3.3037186 ],
#        [-3.2026458 ],
#        [-3.1341417 ],
#        [-3.1491365 ],
#        [-3.2724454 ],
#        [-2.7121384 ],
#        [-2.624679  ],
#        [-2.7004585 ],
#        [-2.8215437 ],
#        [-3.1076639 ],
#        [-3.1437404 ],
#        [-3.2828298 ],
#        [-3.3258524 ],
#        [-3.2854638 ],
#        [-2.9715354 ],
#        [-3.232586  ],
#        [-3.267012  ],
#        [-3.3069904 ],
#        [-3.4145768 ],
#        [-3.2521462 ],
#        [-3.3109207 ],
#        [-3.1257946 ],
#        [-3.1637824 ],
#        [-3.0781515 ],
#        [-3.0455084 ],
#        [-3.1350095 ],
#        [-3.163915  ],
#        [-3.0581074 ],
#        [-3.0195434 ],
#        [-2.9148364 ],
#        [-2.8929865 ],
#        [-2.874843  ],
#        [-2.647463  ],
#        [-2.646144  ],
#        [-2.6137574 ],
#        [-2.654984  ],
#        [-2.7931106 ],
#        [-2.746608  ],
#        [-2.8153079 ],
#        [-2.763263  ],
#        [-2.7568753 ],
#        [-2.8617935 ],
#        [-3.060409  ],
#        [-3.0792563 ],
#        [-3.2186713 ],
#        [-3.1877706 ],
#        [-3.264904  ],
#        [-3.4980562 ],
#        [-3.4770963 ],
#        [-3.4153366 ],
#        [-3.530348  ],
#        [-3.4753163 ],
#        [-3.5132387 ],
#        [-3.578554  ],
#        [-3.4918067 ],
#        [-3.4407737 ],
#        [-3.4541526 ],
#        [-3.5362992 ],
#        [-3.6201665 ],
#        [-3.6688936 ],
#        [-3.6833434 ],
#        [-3.6063545 ],
#        [-3.8302174 ],
#        [-3.729262  ],
#        [-3.7113607 ],
#        [-3.8218439 ],
#        [-3.9164631 ],
#        [-3.861157  ],
#        [-3.8738413 ],
#        [-3.9542422 ],
#        [-3.7737014 ],
#        [-4.0869026 ],
#        [-4.1294317 ],
#        [-4.2319493 ],
#        [-4.370063  ],
#        [-4.633401  ],
#        [-4.689894  ],
#        [-4.899049  ],
#        [-4.9150405 ],
#        [-4.927587  ],
#        [-4.8685412 ],
#        [-4.752338  ],
#        [-4.887405  ],
#        [-4.8438606 ],
#        [-5.002009  ],
#        [-4.8867774 ],
#        [-5.001242  ],
#        [-4.9757986 ],
#        [-4.926208  ],
#        [-5.0257154 ],
#        [-4.9886003 ],
#        [-5.017609  ],
#        [-5.046984  ],
#        [-5.1052246 ],
#        [-5.089567  ],
#        [-5.066911  ],
#        [-4.8518453 ],
#        [-4.8719444 ]], dtype=float32)

# %%
df_lstm
# Out:
#              Actual      Pred     Error
# Date
# 2021-10-25  6.30670  5.736749  0.569951
# 2021-10-26  6.03108  5.746667  0.284413
# 2021-10-27  5.84381  5.756585  0.087225
# 2021-10-28  6.05825  5.766503  0.291747
# 2021-10-29  6.22428  5.776421  0.447859
# ...             ...       ...       ...
# 2022-05-28  2.90271  7.869147 -4.966437
# 2022-05-29  2.94652  7.879065 -4.932545
# 2022-05-30  3.17233  7.888983 -4.716653
# 2022-05-31  3.17934  7.898902 -4.719562
# 2022-06-01  2.97985  7.908820 -4.928970
#
# [220 rows x 3 columns]

# %%
df_lstm = df_lstm.copy().head(len(error_pred))
df_lstm['Error Prediction'] = error_pred
df_lstm
# Out:
#              Actual      Pred     Error  Error Prediction
# Date
# 2021-10-25  6.30670  5.736749  0.569951          0.147008
# 2021-10-26  6.03108  5.746667  0.284413          0.362625
# 2021-10-27  5.84381  5.756585  0.087225          0.438548
# 2021-10-28  6.05825  5.766503  0.291747          0.378641
# 2021-10-29  6.22428  5.776421  0.447859          0.355580
# ...             ...       ...       ...               ...
# 2022-05-25  2.95406  7.839393 -4.885333         -5.105225
# 2022-05-26  2.92035  7.849311 -4.928961         -5.089567
# 2022-05-27  2.86012  7.859229 -4.999109         -5.066911
# 2022-05-28  2.90271  7.869147 -4.966437         -4.851845
# 2022-05-29  2.94652  7.879065 -4.932545         -4.871944
#
# [217 rows x 4 columns]

# %%
df_lstm['LR_LSTM'] = df_lstm['Pred'] + df_lstm['Error Prediction']
df_lstm
# Out:
#              Actual      Pred     Error  Error Prediction   LR_LSTM
# Date
# 2021-10-25  6.30670  5.736749  0.569951          0.147008  5.883756
# 2021-10-26  6.03108  5.746667  0.284413          0.362625  6.109292
# 2021-10-27  5.84381  5.756585  0.087225          0.438548  6.195132
# 2021-10-28  6.05825  5.766503  0.291747          0.378641  6.145144
# 2021-10-29  6.22428  5.776421  0.447859          0.355580  6.132001
# ...             ...       ...       ...               ...       ...
# 2022-05-25  2.95406  7.839393 -4.885333         -5.105225  2.734168
# 2022-05-26  2.92035  7.849311 -4.928961         -5.089567  2.759744
# 2022-05-27  2.86012  7.859229 -4.999109         -5.066911  2.792318
# 2022-05-28  2.90271  7.869147 -4.966437         -4.851845  3.017302
# 2022-05-29  2.94652  7.879065 -4.932545         -4.871944  3.007121
#
# [217 rows x 5 columns]

# %% [markdown]
# ## Vẽ đồ thị

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_lstm['Actual'], 'blue', label='Actual data')
plt.plot(df_lstm['LR_LSTM'], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# ## Đánh giá mô hình

# %%
from sklearn.metrics import r2_score
mae = mean_absolute_error(df_lstm.Actual, df_lstm.LR_LSTM)
mape = mean_absolute_percentage_error(df_lstm.Actual, df_lstm.LR_LSTM)
mse = mean_squared_error(df_lstm.Actual, df_lstm.LR_LSTM)
rmse = np.sqrt(mse)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 0.18
# MAPE: 4.15%
# MSE: 0.05
# RMSE: 0.23
# R2: -8.25

# %% [markdown]
# ## Lấy 3 ngày cuối ra để dự báo

# %%
forecast = df_lstm['Error'].tail(3)
forecast
# Out:
# Date
# 2022-05-27   -4.999109
# 2022-05-28   -4.966437
# 2022-05-29   -4.932545
# Name: Error, dtype: float64

# %% [markdown]
# ## Đưa về ma trận

# %%
dataX = []
for i in range(len(forecast)):
    a=forecast[i]
    dataX.append(a)
dataX = np.array(dataX).reshape(1,-1,1)
dataX
# Out:
# array([[[-4.99910905],
#         [-4.96643718],
#         [-4.93254532]]])

# %%
y_forecast= model.predict(dataX).reshape(1,)
y_forecast
# Out:
# array([-5.0669107], dtype=float32)

# %% [markdown]
# ## So sánh kết quả dự đoán với giá trị thực

# %%
y_LR = df_pred.copy()
y_LR = y_LR.tail(4).head(1)
y_LR
# Out:
#              Actual      Pred     Error
# Date
# 2022-05-29  2.94652  7.879065 -4.932545

# %%
y_LR['Final_LSTM'] = y_LR.Pred + y_forecast
y_LR
# Out:
#              Actual      Pred     Error  Final_LSTM
# Date
# 2022-05-29  2.94652  7.879065 -4.932545    2.812155

# %% [markdown]
# ## Ghi ra file csv

# %%
df.to_csv("processed_data.csv")
df_scaled.to_csv("scaled_data.csv")
df_pred.to_csv("LR-PRED.csv")
df_lstm.to_csv("LSTM_PRED.csv")
y_LR.to_csv("Forecast.csv")
