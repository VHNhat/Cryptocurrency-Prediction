# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình ARIMA

# %% [markdown]
# # Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pmdarima as pmd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.utils import column_or_1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model

# %% [markdown]
# # Nạp dữ liệu từ file csv

# %%
df = pd.read_csv('xrp.csv')
df.pop('Currency')
df.pop('Volume')
df.pop('High')
df.pop('Low')
df.pop('Open')

df['Date'] = pd.to_datetime(df['Date'])
df.set_index("Date",inplace=True)
df_close = df['Close'].values.reshape(-1, 1)

df
# Out:
#               Close
# Date
# 2020-06-01  0.21090
# 2020-06-02  0.20317
# 2020-06-03  0.20411
# 2020-06-04  0.20438
# 2020-06-05  0.20282
# ...             ...
# 2022-05-28  0.38637
# 2022-05-29  0.38910
# 2022-05-30  0.41859
# 2022-05-31  0.42156
# 2022-06-01  0.39802
#
# [731 rows x 1 columns]

# %% [markdown]
# # Chuẩn hóa dữ liệu

# %%
arima_sc = StandardScaler()

df_scaled = df.copy()
df_scaled['Close'] = arima_sc.fit_transform(df_close)
df_scaled
# Out:
#                Close
# Date
# 2020-06-01 -1.244092
# 2020-06-02 -1.265447
# 2020-06-03 -1.262850
# 2020-06-04 -1.262104
# 2020-06-05 -1.266414
# ...              ...
# 2022-05-28 -0.759352
# 2022-05-29 -0.751810
# 2022-05-30 -0.670343
# 2022-05-31 -0.662138
# 2022-06-01 -0.727168
#
# [731 rows x 1 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'XRP Price'
ylabel = 'USD'
xlabel = 'Date'

ax = df['Close'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %% [markdown]
# # Tách dữ liệu thành tập train và test

# %%
train, test = df_scaled[:(int)(len(df_scaled) * 0.8)], df_scaled[(int)(len(df_scaled) * 0.8):]
index_test = df_scaled.index[(int)(len(df_scaled) * 0.8):]
print('train shape: ', train.shape)
print('test shape: ', test.shape)
# Out:
# train shape:  (584, 1)
# test shape:  (147, 1)

# %% [markdown]
# # Hàm kiểm định chuỗi dừng

# %%
def adf_test(series, title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    # .dropna() handles differenced data
    result = adfuller(series.dropna(), autolag='AIC')

    labels = ['ADF test statistic', 'p-value',
              'Number of lags used', 'Number of observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val

    # .to_string() removes the line "dtype: float64"
    print(out.to_string())

    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non stationary")

# %% [markdown]
# # Kiểm định tính dừng của chuỗi

# %%
adf_test(train['Close'],'XRP Price')
# Out:
# Augmented Dickey-Fuller Test: XRP Price
# ADF test statistic         -2.078090
# p-value                     0.253416
# Number of lags used        18.000000
# Number of observations    565.000000
# critical value (1%)        -3.441977
# critical value (5%)        -2.866669
# critical value (10%)       -2.569502
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non stationary

# %% [markdown]
# nhận thấy p-value > 0.05, do đó chuỗi không phải là chuỗi dừng

# %% [markdown]
# # Tính sai phân bậc 1 (d = 1) của chuỗi để kiểm định tính dừng

# %%
diff_1 = train.diff().dropna()
diff_1.plot(figsize=(12,5));

# %% [markdown]
# # Kiểm định tính dừng của chuỗi tại sai phân bậc 1

# %%
adf_test(diff_1, 'XRP Price First Difference')
# Out:
# Augmented Dickey-Fuller Test: XRP Price First Difference
# ADF test statistic       -8.196913e+00
# p-value                   7.406937e-13
# Number of lags used       1.100000e+01
# Number of observations    5.710000e+02
# critical value (1%)      -3.441854e+00
# critical value (5%)      -2.866615e+00
# critical value (10%)     -2.569473e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# Nhận thấy p-value < 0.05, do đó chuỗi có tính dừng tại sai phân bậc 1

# %%
def ArimaModel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              test="adf",
                              seasonal=False,
                              trace=True)
    return autoarima_model

# %%
arima_model = ArimaModel(train)
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-424.174, Time=1.69 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-424.893, Time=0.14 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-425.324, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-425.292, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-426.746, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-423.328, Time=0.15 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 2.307 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  584
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 214.373
# Date:                Sat, 25 Jun 2022   AIC                           -426.746
# Time:                        18:12:31   BIC                           -422.378
# Sample:                             0   HQIC                          -425.044
#                                 - 584
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0281      0.001     52.091      0.000       0.027       0.029
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.44   Jarque-Bera (JB):              6730.06
# Prob(Q):                              0.12   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.80   Skew:                            -0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.64
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Dự đoán trên tập test

# %%
pred = arima_model.predict(len(test))
pred
# Out:
# array([0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025, 0.30389025, 0.30389025, 0.30389025,
#        0.30389025, 0.30389025])

# %% [markdown]
# # Biến đổi giá trị dự đoán và thực tế về miền giá trị ban đầu

# %%
inv_test = arima_sc.inverse_transform(test.values.reshape(-1, 1))
inv_pred = arima_sc.inverse_transform(column_or_1d(pred).reshape(-1, 1))

# %% [markdown]
# # Vẽ đồ thị cho tập test và kết quả dự đoán

# %%
pred_series = pd.Series(pred, index=index_test)

plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(inv_test, 'blue', label='Actual data')
plt.plot(inv_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(inv_test, inv_pred)
mape = mean_absolute_percentage_error(inv_test, inv_pred)
mse = mean_squared_error(inv_test, inv_pred)
rmse = np.sqrt(mse)
r2 = r2_score(inv_test, inv_pred)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 0.11
# MAPE: 22.06%
# MSE: 0.03
# RMSE: 0.16
# R2: -0.37

# %% [markdown]
# # Tạo một DataFrame là 'df_pred' để lưu kết quả dự đoán trên mô hình ARIMA

# %%
df_pred = pd.DataFrame(index=index_test)
df_pred['Actual'] = inv_test
df_pred['ARIMA'] = inv_pred
df_pred['Error'] = inv_test - inv_pred
df_pred
# Out:
#              Actual    ARIMA    Error
# Date
# 2022-01-06  0.77960  0.77125  0.00835
# 2022-01-07  0.76260  0.77125 -0.00865
# 2022-01-08  0.74471  0.77125 -0.02654
# 2022-01-09  0.75283  0.77125 -0.01842
# 2022-01-10  0.74013  0.77125 -0.03112
# ...             ...      ...      ...
# 2022-05-28  0.38637  0.77125 -0.38488
# 2022-05-29  0.38910  0.77125 -0.38215
# 2022-05-30  0.41859  0.77125 -0.35266
# 2022-05-31  0.42156  0.77125 -0.34969
# 2022-06-01  0.39802  0.77125 -0.37323
#
# [147 rows x 3 columns]

# %% [markdown]
# ## 2. Quá trình dự đoán trên mô hình LSTM

# %% [markdown]
# # Tạo thêm một DataFrame để tiến hành dự đoán sai số trên mô hình LSTM

# %%
df_lstm = df_pred.copy()
df_lstm
# Out:
#              Actual    ARIMA    Error
# Date
# 2022-01-06  0.77960  0.77125  0.00835
# 2022-01-07  0.76260  0.77125 -0.00865
# 2022-01-08  0.74471  0.77125 -0.02654
# 2022-01-09  0.75283  0.77125 -0.01842
# 2022-01-10  0.74013  0.77125 -0.03112
# ...             ...      ...      ...
# 2022-05-28  0.38637  0.77125 -0.38488
# 2022-05-29  0.38910  0.77125 -0.38215
# 2022-05-30  0.41859  0.77125 -0.35266
# 2022-05-31  0.42156  0.77125 -0.34969
# 2022-06-01  0.39802  0.77125 -0.37323
#
# [147 rows x 3 columns]

# %% [markdown]
# # Vẽ đồ thị thể hiện sai số

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

error = df_lstm[['Error']]
title = 'Residual from ARIMA model'
ylabel = 'USD'
xlabel = 'Date'

ax = error.plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
error = np.array(error)
error
# Out:
# array([[ 0.00835],
#        [-0.00865],
#        [-0.02654],
#        [-0.01842],
#        [-0.03112],
#        [-0.00139],
#        [ 0.02663],
#        [-0.00401],
#        [ 0.00198],
#        [ 0.00809],
#        [ 0.00718],
#        [-0.00978],
#        [-0.01989],
#        [-0.03326],
#        [-0.05081],
#        [-0.13393],
#        [-0.17451],
#        [-0.14252],
#        [-0.15917],
#        [-0.15365],
#        [-0.15229],
#        [-0.16288],
#        [-0.15997],
#        [-0.15385],
#        [-0.16977],
#        [-0.15379],
#        [-0.14302],
#        [-0.17043],
#        [-0.16164],
#        [-0.11562],
#        [-0.10508],
#        [-0.08854],
#        [ 0.05991],
#        [ 0.10493],
#        [ 0.09855],
#        [ 0.05426],
#        [-0.01229],
#        [ 0.05046],
#        [ 0.0342 ],
#        [ 0.02952],
#        [ 0.07958],
#        [ 0.06457],
#        [-0.00448],
#        [ 0.01343],
#        [ 0.05035],
#        [ 0.00437],
#        [-0.06963],
#        [-0.05006],
#        [-0.07523],
#        [-0.07525],
#        [-0.00199],
#        [-0.02081],
#        [-0.04981],
#        [ 0.01002],
#        [ 0.01259],
#        [-0.0024 ],
#        [-0.01945],
#        [-0.05848],
#        [-0.01734],
#        [-0.04652],
#        [-0.05113],
#        [-0.05045],
#        [-0.00554],
#        [-0.03515],
#        [ 0.03187],
#        [ 0.0146 ],
#        [-0.01182],
#        [ 0.0033 ],
#        [-0.00538],
#        [ 0.02065],
#        [ 0.02206],
#        [ 0.02536],
#        [ 0.04845],
#        [ 0.03481],
#        [ 0.06611],
#        [ 0.06535],
#        [ 0.0664 ],
#        [ 0.07154],
#        [ 0.05283],
#        [ 0.06161],
#        [ 0.0865 ],
#        [ 0.09157],
#        [ 0.08646],
#        [ 0.0901 ],
#        [ 0.04379],
#        [ 0.05649],
#        [ 0.05244],
#        [ 0.07187],
#        [ 0.05522],
#        [ 0.04518],
#        [-0.01168],
#        [ 0.01631],
#        [-0.01605],
#        [-0.00904],
#        [-0.01705],
#        [-0.07667],
#        [-0.05663],
#        [-0.04849],
#        [-0.04497],
#        [ 0.01435],
#        [ 0.00979],
#        [-0.01934],
#        [-0.00208],
#        [ 0.00353],
#        [-0.01961],
#        [-0.03845],
#        [-0.05347],
#        [-0.06578],
#        [-0.0729 ],
#        [-0.07817],
#        [-0.12886],
#        [-0.11914],
#        [-0.12846],
#        [-0.15972],
#        [-0.18602],
#        [-0.16423],
#        [-0.15687],
#        [-0.16664],
#        [-0.12516],
#        [-0.17316],
#        [-0.16907],
#        [-0.1905 ],
#        [-0.20506],
#        [-0.28359],
#        [-0.25804],
#        [-0.35556],
#        [-0.38635],
#        [-0.34843],
#        [-0.34516],
#        [-0.3233 ],
#        [-0.34829],
#        [-0.33336],
#        [-0.36602],
#        [-0.35099],
#        [-0.36104],
#        [-0.35676],
#        [-0.34945],
#        [-0.36616],
#        [-0.36267],
#        [-0.36505],
#        [-0.3786 ],
#        [-0.38976],
#        [-0.38488],
#        [-0.38215],
#        [-0.35266],
#        [-0.34969],
#        [-0.37323]])

# %%
look_back = 3
x_total, y_total = [], []
for i in range(look_back, len(error)):
	x_total.append(error[i-look_back:i])
	y_total.append(error[i])
x_train = np.array(x_total[:len(error)])
y_train = np.array(y_total[:len(error)])

print("x_train",x_train.shape)
print("y_train",y_train.shape)
# Out:
# x_train (144, 3, 1)
# y_train (144, 1)

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(x_train, y_train, epochs=300, verbose=1)
model.save("xrp_8_2.h5")
# Out:
# Epoch 1/300
# 5/5 [==============================] - 4s 7ms/step - loss: 0.0264
# Epoch 2/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0240
# Epoch 3/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0217
# Epoch 4/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0195
# Epoch 5/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0175
# Epoch 6/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0152
# Epoch 7/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0130
# Epoch 8/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 9/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0080
# Epoch 10/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0054
# Epoch 11/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0033
# Epoch 12/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 13/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 14/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0021
# Epoch 15/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0020
# Epoch 16/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0018
# Epoch 17/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 18/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 19/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 20/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 21/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 22/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 23/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 24/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 25/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 26/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 27/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 28/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 29/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 30/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 31/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 32/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0018
# Epoch 33/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 34/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 35/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 36/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 37/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 38/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 39/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 40/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 41/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 42/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 43/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 44/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 45/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 46/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 47/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 48/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 49/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 50/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 51/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0017
# Epoch 52/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 53/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 54/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 55/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 56/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 57/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 58/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 59/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 60/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017
# Epoch 61/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 62/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 63/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 64/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 65/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0016
# Epoch 66/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 67/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 68/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 69/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 70/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0016
# Epoch 71/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 72/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 73/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 74/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 75/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 76/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 77/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 78/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 79/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 80/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 81/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 82/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 83/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 84/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 85/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 86/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 87/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 88/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0015
# Epoch 89/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 90/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 91/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 92/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 93/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 94/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 95/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 96/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 97/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 98/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 99/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 100/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 101/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 102/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 103/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 104/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 105/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 106/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 107/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 108/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0015
# Epoch 109/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 110/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 111/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 112/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 113/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 114/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 115/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 116/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0014
# Epoch 117/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 118/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 119/300
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0014
# Epoch 120/300
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0014
# Epoch 121/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0014
# Epoch 122/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 123/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 124/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 125/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 126/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 127/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 128/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 129/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0014
# Epoch 130/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 131/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 132/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 133/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 134/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0014
# Epoch 135/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 136/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 137/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 138/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 139/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 140/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 141/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 142/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 143/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 144/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 145/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 146/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 147/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 148/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 149/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0013
# Epoch 150/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 151/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 152/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 153/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 154/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 155/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 156/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0013
# Epoch 157/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0013
# Epoch 158/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 159/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 160/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 161/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 162/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 163/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 164/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 165/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 166/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 167/300
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 168/300
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0012
# Epoch 169/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 170/300
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0012
# Epoch 171/300
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0012
# Epoch 172/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 173/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 174/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 175/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 176/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 177/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 178/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 179/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0012
# Epoch 180/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 181/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 182/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0012
# Epoch 183/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 184/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 185/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 186/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 187/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 188/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 189/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 190/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 191/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 192/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 193/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 194/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 195/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 196/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 197/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 198/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 199/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 200/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 201/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 202/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 203/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 204/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 205/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 206/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 207/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 208/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 209/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 210/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 211/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 212/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 213/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 214/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 215/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 216/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 217/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 218/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 219/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0011
# Epoch 220/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 221/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 222/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 223/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 224/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.9522e-04
# Epoch 225/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 226/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 227/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 228/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 229/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 230/300
# 5/5 [==============================] - 0s 33ms/step - loss: 9.9949e-04
# Epoch 231/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.6830e-04
# Epoch 232/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 233/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.9476e-04
# Epoch 234/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.7364e-04
# Epoch 235/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.6786e-04
# Epoch 236/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.7906e-04
# Epoch 237/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0010
# Epoch 238/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 239/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.8315e-04
# Epoch 240/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 241/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.6588e-04
# Epoch 242/300
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 243/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 244/300
# 5/5 [==============================] - 0s 7ms/step - loss: 0.0011
# Epoch 245/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.8043e-04
# Epoch 246/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 247/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 248/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 249/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.8186e-04
# Epoch 250/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 251/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 252/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.6990e-04
# Epoch 253/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.6863e-04
# Epoch 254/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.7166e-04
# Epoch 255/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.8199e-04
# Epoch 256/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.6885e-04
# Epoch 257/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.5644e-04
# Epoch 258/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 259/300
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 260/300
# 5/5 [==============================] - 0s 12ms/step - loss: 9.4367e-04
# Epoch 261/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.8236e-04
# Epoch 262/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.5693e-04
# Epoch 263/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.3985e-04
# Epoch 264/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.6359e-04
# Epoch 265/300
# 5/5 [==============================] - 0s 15ms/step - loss: 9.8269e-04
# Epoch 266/300
# 5/5 [==============================] - 0s 15ms/step - loss: 9.5871e-04
# Epoch 267/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.9100e-04
# Epoch 268/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.3987e-04
# Epoch 269/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.6576e-04
# Epoch 270/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.5017e-04
# Epoch 271/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.7602e-04
# Epoch 272/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.2878e-04
# Epoch 273/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.6479e-04
# Epoch 274/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.3971e-04
# Epoch 275/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.6105e-04
# Epoch 276/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.5354e-04
# Epoch 277/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.4311e-04
# Epoch 278/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.8300e-04
# Epoch 279/300
# 5/5 [==============================] - 0s 11ms/step - loss: 9.6122e-04
# Epoch 280/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.5439e-04
# Epoch 281/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.4977e-04
# Epoch 282/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.6631e-04
# Epoch 283/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.8660e-04
# Epoch 284/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.3512e-04
# Epoch 285/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.4393e-04
# Epoch 286/300
# 5/5 [==============================] - 0s 10ms/step - loss: 9.3463e-04
# Epoch 287/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.3700e-04
# Epoch 288/300
# 5/5 [==============================] - 0s 9ms/step - loss: 9.4960e-04
# Epoch 289/300
# 5/5 [==============================] - 0s 17ms/step - loss: 9.4734e-04
# Epoch 290/300
# 5/5 [==============================] - 0s 12ms/step - loss: 9.3038e-04
# Epoch 291/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.4173e-04
# Epoch 292/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.3756e-04
# Epoch 293/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.4435e-04
# Epoch 294/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.3151e-04
# Epoch 295/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.5718e-04
# Epoch 296/300
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 297/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.5543e-04
# Epoch 298/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.5418e-04
# Epoch 299/300
# 5/5 [==============================] - 0s 7ms/step - loss: 9.5484e-04
# Epoch 300/300
# 5/5 [==============================] - 0s 8ms/step - loss: 9.7294e-04

# %%
model = load_model("xrp_8_2.h5")
error_pred = model.predict(x_train)
error_pred
# Out:
# 5/5 [==============================] - 1s 4ms/step
# array([[-2.4809606e-02],
#        [-1.8477596e-02],
#        [-2.8935248e-02],
#        [-3.3371858e-03],
#        [ 2.0223796e-02],
#        [-6.7060813e-03],
#        [-1.7656200e-03],
#        [ 4.3294728e-03],
#        [ 3.4090094e-03],
#        [-1.0937676e-02],
#        [-1.9118115e-02],
#        [-3.0536477e-02],
#        [-4.6165340e-02],
#        [-1.1981523e-01],
#        [-1.8498147e-01],
#        [-1.5577656e-01],
#        [-1.5943360e-01],
#        [-1.5761405e-01],
#        [-1.5443201e-01],
#        [-1.6337568e-01],
#        [-1.6542915e-01],
#        [-1.5918687e-01],
#        [-1.7072380e-01],
#        [-1.6291235e-01],
#        [-1.4827678e-01],
#        [-1.6616398e-01],
#        [-1.7007890e-01],
#        [-1.2664270e-01],
#        [-9.7336456e-02],
#        [-8.0241427e-02],
#        [ 5.3857081e-02],
#        [ 8.5053958e-02],
#        [ 7.6677613e-02],
#        [ 4.0720142e-02],
#        [-1.3079241e-02],
#        [ 3.4451745e-02],
#        [ 2.4804033e-02],
#        [ 2.1904647e-02],
#        [ 6.3943185e-02],
#        [ 4.9436793e-02],
#        [-6.7787506e-03],
#        [ 3.3885986e-03],
#        [ 3.9935745e-02],
#        [-1.4144927e-04],
#        [-6.3517340e-02],
#        [-6.0758311e-02],
#        [-6.7119405e-02],
#        [-7.1885563e-02],
#        [-3.2444447e-03],
#        [-2.0951824e-02],
#        [-4.5322288e-02],
#        [ 4.0320978e-03],
#        [ 7.6847710e-03],
#        [-4.7931522e-03],
#        [-1.8859603e-02],
#        [-5.2511137e-02],
#        [-2.1978222e-02],
#        [-4.2691730e-02],
#        [-4.8823569e-02],
#        [-4.5634948e-02],
#        [-5.9279278e-03],
#        [-3.3058114e-02],
#        [ 2.3087285e-02],
#        [ 8.6742193e-03],
#        [-1.2539465e-02],
#        [-4.0015951e-04],
#        [-7.2849169e-03],
#        [ 1.5319336e-02],
#        [ 1.5611902e-02],
#        [ 1.8531032e-02],
#        [ 3.7912868e-02],
#        [ 2.5654495e-02],
#        [ 5.2467123e-02],
#        [ 5.0631799e-02],
#        [ 5.1704675e-02],
#        [ 5.5916496e-02],
#        [ 4.0267475e-02],
#        [ 4.8203073e-02],
#        [ 6.8453938e-02],
#        [ 7.1685649e-02],
#        [ 6.7299657e-02],
#        [ 7.0445254e-02],
#        [ 3.2352880e-02],
#        [ 4.3243088e-02],
#        [ 4.0267706e-02],
#        [ 5.6654826e-02],
#        [ 4.2108305e-02],
#        [ 3.4514911e-02],
#        [-1.2766350e-02],
#        [ 7.0483051e-03],
#        [-1.6786236e-02],
#        [-1.1752792e-02],
#        [-1.6968412e-02],
#        [-6.7926139e-02],
#        [-6.4186066e-02],
#        [-4.3491945e-02],
#        [-4.0466424e-02],
#        [ 1.1215255e-02],
#        [ 5.1330812e-03],
#        [-1.9050032e-02],
#        [-5.5466108e-03],
#        [ 4.5627728e-04],
#        [-1.9345306e-02],
#        [-3.5994887e-02],
#        [-4.9315013e-02],
#        [-6.0305037e-02],
#        [-6.6836633e-02],
#        [-7.1239956e-02],
#        [-1.1618899e-01],
#        [-1.2701318e-01],
#        [-1.1944667e-01],
#        [-1.5390389e-01],
#        [-1.9007280e-01],
#        [-1.8028066e-01],
#        [-1.7069086e-01],
#        [-1.6989216e-01],
#        [-1.3517316e-01],
#        [-1.6242696e-01],
#        [-1.8138593e-01],
#        [-2.0013481e-01],
#        [-2.2255287e-01],
#        [-2.9279324e-01],
#        [-3.1856668e-01],
#        [-3.4299728e-01],
#        [-3.6011875e-01],
#        [-3.6597845e-01],
#        [-3.6314040e-01],
#        [-3.5478106e-01],
#        [-3.5647953e-01],
#        [-3.5490087e-01],
#        [-3.6173978e-01],
#        [-3.6182010e-01],
#        [-3.6484352e-01],
#        [-3.6395937e-01],
#        [-3.6281896e-01],
#        [-3.6480334e-01],
#        [-3.6572763e-01],
#        [-3.6729464e-01],
#        [-3.7007380e-01],
#        [-3.7445557e-01],
#        [-3.7615767e-01],
#        [-3.7609461e-01],
#        [-3.6918345e-01],
#        [-3.6425915e-01]], dtype=float32)

# %%
df_lstm = df_lstm.copy().head(len(error_pred))
df_lstm['Error Prediction'] = error_pred
df_lstm
# Out:
#              Actual    ARIMA    Error  Error Prediction
# Date
# 2022-01-06  0.77960  0.77125  0.00835         -0.024810
# 2022-01-07  0.76260  0.77125 -0.00865         -0.018478
# 2022-01-08  0.74471  0.77125 -0.02654         -0.028935
# 2022-01-09  0.75283  0.77125 -0.01842         -0.003337
# 2022-01-10  0.74013  0.77125 -0.03112          0.020224
# ...             ...      ...      ...               ...
# 2022-05-25  0.40620  0.77125 -0.36505         -0.374456
# 2022-05-26  0.39265  0.77125 -0.37860         -0.376158
# 2022-05-27  0.38149  0.77125 -0.38976         -0.376095
# 2022-05-28  0.38637  0.77125 -0.38488         -0.369183
# 2022-05-29  0.38910  0.77125 -0.38215         -0.364259
#
# [144 rows x 4 columns]

# %%
df_lstm['ARIMA_LSTM'] = df_lstm['ARIMA'] + df_lstm['Error Prediction']
df_lstm
# Out:
#              Actual    ARIMA    Error  Error Prediction  ARIMA_LSTM
# Date
# 2022-01-06  0.77960  0.77125  0.00835         -0.024810    0.746440
# 2022-01-07  0.76260  0.77125 -0.00865         -0.018478    0.752772
# 2022-01-08  0.74471  0.77125 -0.02654         -0.028935    0.742315
# 2022-01-09  0.75283  0.77125 -0.01842         -0.003337    0.767913
# 2022-01-10  0.74013  0.77125 -0.03112          0.020224    0.791474
# ...             ...      ...      ...               ...         ...
# 2022-05-25  0.40620  0.77125 -0.36505         -0.374456    0.396794
# 2022-05-26  0.39265  0.77125 -0.37860         -0.376158    0.395092
# 2022-05-27  0.38149  0.77125 -0.38976         -0.376095    0.395155
# 2022-05-28  0.38637  0.77125 -0.38488         -0.369183    0.402067
# 2022-05-29  0.38910  0.77125 -0.38215         -0.364259    0.406991
#
# [144 rows x 5 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_lstm['Actual'], 'blue', label='Actual data')
plt.plot(df_lstm['ARIMA_LSTM'], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mape = mean_absolute_percentage_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mse = mean_squared_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
rmse = np.sqrt(mse)
r2 = r2_score(df_lstm.Actual, df_lstm.ARIMA_LSTM)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 0.03
# MAPE: 4.47%
# MSE: 0.00
# RMSE: 0.04
# R2: 0.90

# %% [markdown]
# # Lấy 3 ngày cuối ra để dự báo

# %%
forecast = df_lstm['Error'].tail(3)
forecast
# Out:
# Date
# 2022-05-27   -0.38976
# 2022-05-28   -0.38488
# 2022-05-29   -0.38215
# Name: Error, dtype: float64

# %% [markdown]
# # Đưa về ma trận

# %%
dataX = []
for i in range(len(forecast)):
    a=forecast[i]
    dataX.append(a)
dataX = np.array(dataX).reshape(1,-1,1)
dataX
# Out:
# array([[[-0.38976],
#         [-0.38488],
#         [-0.38215]]])

# %%
y_forecast= model.predict(dataX).reshape(1,)
y_forecast
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([-0.37609455], dtype=float32)

# %% [markdown]
# # So sánh kết quả dự đoán với giá trị thực

# %%
y_arima = df_pred.copy()
y_arima = y_arima.tail(4).head(1)
y_arima
# Out:
#             Actual    ARIMA    Error
# Date
# 2022-05-29  0.3891  0.77125 -0.38215

# %%
y_arima['Final_LSTM'] = y_arima.ARIMA + y_forecast
y_arima
# Out:
#             Actual    ARIMA    Error  Final_LSTM
# Date
# 2022-05-29  0.3891  0.77125 -0.38215    0.395155

# %% [markdown]
# # Ghi ra file csv

# %%
df.to_csv("xrp_processed_data_8_2.csv")
df_scaled.to_csv("xrp_scaled_data_8_2.csv")
df_pred.to_csv("xrp_ARIMA-PRED_8_2.csv")
df_lstm.to_csv("xrp_LSTM_PRED_8_2.csv")
y_arima.to_csv("xrp_Forecast_8_2.csv")
