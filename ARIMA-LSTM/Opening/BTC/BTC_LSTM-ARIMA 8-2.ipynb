# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình ARIMA

# %% [markdown]
# # Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import pmdarima as pmd
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA

from sklearn.metrics import mean_squared_error
from sklearn.utils import column_or_1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import load_model

# %% [markdown]
# # Nạp dữ liệu từ file csv

# %%
df = pd.read_csv('bitcoin.csv')
df.pop('Currency')
df.pop('Volume')
df.pop('High')
df.pop('Low')
df.pop('Close')

df['Date'] = pd.to_datetime(df['Date'])
df.set_index("Date",inplace=True)
df_close = df['Open'].values.reshape(-1, 1)

df
# Out:
#                Open
# Date
# 2020-06-01   9.4545
# 2020-06-02  10.1907
# 2020-06-03   9.5270
# 2020-06-04   9.6672
# 2020-06-05   9.7940
# ...             ...
# 2022-05-28  28.6201
# 2022-05-29  29.0271
# 2022-05-30  29.4652
# 2022-05-31  31.7302
# 2022-06-01  31.7931
#
# [731 rows x 1 columns]

# %% [markdown]
# # Chuẩn hóa dữ liệu

# %%
arima_sc = StandardScaler()

df_scaled = df.copy()
df_scaled['Open'] = arima_sc.fit_transform(df_close)
df_scaled
# Out:
#                 Open
# Date
# 2020-06-01 -1.566754
# 2020-06-02 -1.522736
# 2020-06-03 -1.562419
# 2020-06-04 -1.554036
# 2020-06-05 -1.546455
# ...              ...
# 2022-05-28 -0.420844
# 2022-05-29 -0.396509
# 2022-05-30 -0.370315
# 2022-05-31 -0.234891
# 2022-06-01 -0.231130
#
# [731 rows x 1 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Bitcoin Price'
ylabel = 'USD'
xlabel = 'Date'

ax = df['Open'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %% [markdown]
# # Tách dữ liệu thành tập train và test

# %%
train, test = df_scaled[:(int)(len(df_scaled) * 0.8)], df_scaled[(int)(len(df_scaled) * 0.8):]
index_test = df_scaled.index[(int)(len(df_scaled) * 0.8):]
print('train shape: ', train.shape)
print('test shape: ', test.shape)
# Out:
# train shape:  (584, 1)
# test shape:  (147, 1)

# %% [markdown]
# # Hàm kiểm định chuỗi dừng

# %%
def adf_test(series, title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    # .dropna() handles differenced data
    result = adfuller(series.dropna(), autolag='AIC')

    labels = ['ADF test statistic', 'p-value',
              'Number of lags used', 'Number of observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val

    # .to_string() removes the line "dtype: float64"
    print(out.to_string())

    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non stationary")

# %% [markdown]
# # Kiểm định tính dừng của chuỗi

# %%
adf_test(train['Open'],'Bitcoin Price')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price
# ADF test statistic         -1.387117
# p-value                     0.588436
# Number of lags used         0.000000
# Number of observations    583.000000
# critical value (1%)        -3.441616
# critical value (5%)        -2.866510
# critical value (10%)       -2.569417
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non stationary

# %% [markdown]
# nhận thấy p-value > 0.05, do đó chuỗi không phải là chuỗi dừng

# %% [markdown]
# # Tính sai phân bậc 1 (d = 1) của chuỗi để kiểm định tính dừng

# %%
diff_1 = train.diff().dropna()
diff_1.plot(figsize=(12,5));

# %% [markdown]
# # Kiểm định tính dừng của chuỗi tại sai phân bậc 1

# %%
adf_test(diff_1, 'Bitcoin Price First Difference')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price First Difference
# ADF test statistic        -25.272028
# p-value                     0.000000
# Number of lags used         0.000000
# Number of observations    582.000000
# critical value (1%)        -3.441636
# critical value (5%)        -2.866519
# critical value (10%)       -2.569422
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# Nhận thấy p-value < 0.05, do đó chuỗi có tính dừng tại sai phân bậc 1

# %%
def ArimaModel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              test="adf",
                              seasonal=False,
                              trace=True)
    return autoarima_model

# %%
arima_model = ArimaModel(train)
arima_model.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-1113.586, Time=0.51 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-1120.309, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-1119.660, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-1119.683, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-1121.357, Time=0.09 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-1117.694, Time=0.28 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.191 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  584
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                 561.678
# Date:                Sun, 26 Jun 2022   AIC                          -1121.357
# Time:                        23:46:32   BIC                          -1116.988
# Sample:                             0   HQIC                         -1119.654
#                                 - 584
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2         0.0085      0.000     27.875      0.000       0.008       0.009
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.36   Jarque-Bera (JB):               279.92
# Prob(Q):                              0.24   Prob(JB):                         0.00
# Heteroskedasticity (H):              21.26   Skew:                            -0.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# # Dự đoán trên tập test

# %%
pred = arima_model.predict(len(test))
pred
# Out:
# array([0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208, 0.6083208,
#        0.6083208, 0.6083208, 0.6083208])

# %% [markdown]
# # Biến đổi giá trị dự đoán và thực tế về miền giá trị ban đầu

# %%
inv_test = arima_sc.inverse_transform(test.values.reshape(-1, 1))
inv_pred = arima_sc.inverse_transform(column_or_1d(pred).reshape(-1, 1))

# %% [markdown]
# # Vẽ đồ thị cho tập test và kết quả dự đoán

# %%
pred_series = pd.Series(pred, index=index_test)

plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Opening Prices')
plt.plot(inv_test, 'blue', label='Actual data')
plt.plot(inv_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(inv_test, inv_pred)
mape = mean_absolute_percentage_error(inv_test, inv_pred)
mse = mean_squared_error(inv_test, inv_pred)
rmse = np.sqrt(mse)
r2 = r2_score(inv_test, inv_pred)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 6.79
# MAPE: 19.35%
# MSE: 68.03
# RMSE: 8.25
# R2: -1.94

# %% [markdown]
# # Tạo một DataFrame là 'df_pred' để lưu kết quả dự đoán trên mô hình ARIMA

# %%
df_pred = pd.DataFrame(index=index_test)
df_pred['Actual'] = inv_test
df_pred['ARIMA'] = inv_pred
df_pred['Error'] = inv_test - inv_pred
df_pred
# Out:
#              Actual    ARIMA    Error
# Date
# 2022-01-06  43.4316  45.8331  -2.4015
# 2022-01-07  43.0979  45.8331  -2.7352
# 2022-01-08  41.5513  45.8331  -4.2818
# 2022-01-09  41.6812  45.8331  -4.1519
# 2022-01-10  41.8489  45.8331  -3.9842
# ...             ...      ...      ...
# 2022-05-28  28.6201  45.8331 -17.2130
# 2022-05-29  29.0271  45.8331 -16.8060
# 2022-05-30  29.4652  45.8331 -16.3679
# 2022-05-31  31.7302  45.8331 -14.1029
# 2022-06-01  31.7931  45.8331 -14.0400
#
# [147 rows x 3 columns]

# %% [markdown]
# ## 2. Quá trình dự đoán trên mô hình LSTM

# %% [markdown]
# # Tạo thêm một DataFrame để tiến hành dự đoán sai số trên mô hình LSTM

# %%
df_lstm = df_pred.copy()
df_lstm
# Out:
#              Actual    ARIMA    Error
# Date
# 2022-01-06  43.4316  45.8331  -2.4015
# 2022-01-07  43.0979  45.8331  -2.7352
# 2022-01-08  41.5513  45.8331  -4.2818
# 2022-01-09  41.6812  45.8331  -4.1519
# 2022-01-10  41.8489  45.8331  -3.9842
# ...             ...      ...      ...
# 2022-05-28  28.6201  45.8331 -17.2130
# 2022-05-29  29.0271  45.8331 -16.8060
# 2022-05-30  29.4652  45.8331 -16.3679
# 2022-05-31  31.7302  45.8331 -14.1029
# 2022-06-01  31.7931  45.8331 -14.0400
#
# [147 rows x 3 columns]

# %% [markdown]
# # Vẽ đồ thị thể hiện sai số

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

error = df_lstm[['Error']]
title = 'Residual from ARIMA model'
ylabel = 'USD'
xlabel = 'Date'

ax = error.plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
error = np.array(error)
error
# Out:
# array([[ -2.4015],
#        [ -2.7352],
#        [ -4.2818],
#        [ -4.1519],
#        [ -3.9842],
#        [ -4.004 ],
#        [ -3.0981],
#        [ -1.9331],
#        [ -3.2709],
#        [ -2.7595],
#        [ -2.7539],
#        [ -2.7526],
#        [ -3.6232],
#        [ -3.4678],
#        [ -4.1495],
#        [ -5.135 ],
#        [ -9.3654],
#        [-10.7602],
#        [ -9.5645],
#        [ -9.1418],
#        [ -8.8708],
#        [ -9.033 ],
#        [ -8.6375],
#        [ -8.0966],
#        [ -7.6656],
#        [ -7.9093],
#        [ -7.3575],
#        [ -7.1219],
#        [ -8.9429],
#        [ -8.5453],
#        [ -4.2666],
#        [ -4.4212],
#        [ -3.4479],
#        [ -1.9992],
#        [ -1.7949],
#        [ -1.4442],
#        [ -2.3138],
#        [ -3.4447],
#        [ -3.6276],
#        [ -3.772 ],
#        [ -3.2828],
#        [ -1.2922],
#        [ -1.9476],
#        [ -5.3006],
#        [ -5.833 ],
#        [ -5.7435],
#        [ -7.4781],
#        [ -8.8148],
#        [ -7.5849],
#        [ -8.5829],
#        [ -7.4939],
#        [ -6.6115],
#        [ -6.7165],
#        [ -8.1259],
#        [ -2.6459],
#        [ -1.4128],
#        [ -1.9203],
#        [ -3.3701],
#        [ -6.6903],
#        [ -6.4368],
#        [ -7.4125],
#        [ -7.8125],
#        [ -7.1016],
#        [ -3.8992],
#        [ -6.4106],
#        [ -7.1029],
#        [ -7.0199],
#        [ -8.0436],
#        [ -6.1601],
#        [ -6.5506],
#        [ -4.7144],
#        [ -4.9185],
#        [ -4.0651],
#        [ -3.5921],
#        [ -4.5511],
#        [ -4.8111],
#        [ -3.4601],
#        [ -2.9221],
#        [ -1.8201],
#        [ -1.5021],
#        [ -1.2911],
#        [  1.0259],
#        [  1.2929],
#        [  1.6159],
#        [  1.2379],
#        [ -0.3041],
#        [  0.4659],
#        [ -0.0201],
#        [  0.5739],
#        [  0.7809],
#        [ -0.3391],
#        [ -2.6671],
#        [ -2.3831],
#        [ -3.5581],
#        [ -3.0731],
#        [ -3.6891],
#        [ -6.3261],
#        [ -5.7611],
#        [ -4.7001],
#        [ -5.8971],
#        [ -5.2621],
#        [ -5.4511],
#        [ -6.1331],
#        [ -5.0241],
#        [ -4.3341],
#        [ -4.4631],
#        [ -5.3461],
#        [ -6.1241],
#        [ -6.3991],
#        [ -6.3691],
#        [ -5.3901],
#        [ -7.7201],
#        [ -6.5901],
#        [ -6.0851],
#        [ -7.2431],
#        [ -8.1911],
#        [ -7.3611],
#        [ -7.3181],
#        [ -8.1161],
#        [ -6.1471],
#        [ -9.2931],
#        [ -9.8301],
#        [-10.3651],
#        [-11.7921],
#        [-15.7349],
#        [-14.8251],
#        [-16.7597],
#        [-16.8388],
#        [-16.5479],
#        [-15.7545],
#        [-14.5248],
#        [-15.9764],
#        [-15.3956],
#        [-17.1327],
#        [-15.5272],
#        [-16.6444],
#        [-16.4001],
#        [-15.5458],
#        [-16.7415],
#        [-16.1844],
#        [-16.2952],
#        [-16.6391],
#        [-17.213 ],
#        [-16.806 ],
#        [-16.3679],
#        [-14.1029],
#        [-14.04  ]])

# %%
look_back = 3
x_total, y_total = [], []
for i in range(look_back, len(error)):
	x_total.append(error[i-look_back:i])
	y_total.append(error[i])
x_train = np.array(x_total[:len(error)])
y_train = np.array(y_total[:len(error)])

print("x_train",x_train.shape)
print("y_train",y_train.shape)
# Out:
# x_train
300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6047
# Epoch 200/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6022
# Epoch 201/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6390
# Epoch 202/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5913
# Epoch 203/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6314
# Epoch 204/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5960
# Epoch 205/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6030
# Epoch 206/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6016
# Epoch 207/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5980
# Epoch 208/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6506
# Epoch 209/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5929
# Epoch 210/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6084
# Epoch 211/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5938
# Epoch 212/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5945
# Epoch 213/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6060
# Epoch 214/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5884
# Epoch 215/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5914
# Epoch 216/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6740
# Epoch 217/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5956
# Epoch 218/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6174
# Epoch 219/300
# 5/5 [==============================] - 0s 11ms/step - loss: 1.6362
# Epoch 220/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6075
# Epoch 221/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6253
# Epoch 222/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5863
# Epoch 223/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5793
# Epoch 224/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6071
# Epoch 225/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7081
# Epoch 226/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.6236
# Epoch 227/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.6195
# Epoch 228/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6163
# Epoch 229/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5884
# Epoch 230/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5948
# Epoch 231/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6150
# Epoch 232/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6469
# Epoch 233/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.7929
# Epoch 234/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6066
# Epoch 235/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6099
# Epoch 236/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5785
# Epoch 237/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6281
# Epoch 238/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6531
# Epoch 239/300
# 5/5 [==============================] - 0s 5ms/step - loss: 1.5898
# Epoch 240/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6063
# Epoch 241/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5934
# Epoch 242/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6287
# Epoch 243/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.7234
# Epoch 244/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.7661
# Epoch 245/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.8000
# Epoch 246/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.6217
# Epoch 247/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5832
# Epoch 248/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6190
# Epoch 249/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6131
# Epoch 250/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5847
# Epoch 251/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6080
# Epoch 252/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5792
# Epoch 253/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5719
# Epoch 254/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5677
# Epoch 255/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5612
# Epoch 256/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5876
# Epoch 257/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5641
# Epoch 258/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5576
# Epoch 259/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5537
# Epoch 260/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5609
# Epoch 261/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5522
# Epoch 262/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5828
# Epoch 263/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5712
# Epoch 264/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5703
# Epoch 265/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6436
# Epoch 266/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.6153
# Epoch 267/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5379
# Epoch 268/300
# 5/5 [==============================] - 0s 9ms/step - loss: 1.5929
# Epoch 269/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5670
# Epoch 270/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5331
# Epoch 271/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5482
# Epoch 272/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5311
# Epoch 273/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5804
# Epoch 274/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5427
# Epoch 275/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5928
# Epoch 276/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5707
# Epoch 277/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.6030
# Epoch 278/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5590
# Epoch 279/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.5648
# Epoch 280/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5612
# Epoch 281/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5508
# Epoch 282/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5576
# Epoch 283/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5463
# Epoch 284/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5790
# Epoch 285/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6051
# Epoch 286/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6105
# Epoch 287/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.6492
# Epoch 288/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5518
# Epoch 289/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5655
# Epoch 290/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5535
# Epoch 291/300
# 5/5 [==============================] - 0s 6ms/step - loss: 1.5944
# Epoch 292/300
# 5/5 [==============================] - 0s 21ms/step - loss: 1.6569
# Epoch 293/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.6033
# Epoch 294/300
# 5/5 [==============================] - 0s 12ms/step - loss: 1.5724
# Epoch 295/300
# 5/5 [==============================] - 0s 10ms/step - loss: 1.5394
# Epoch 296/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5741
# Epoch 297/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5340
# Epoch 298/300
# 5/5 [==============================] - 0s 8ms/step - loss: 1.5236
# Epoch 299/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5386
# Epoch 300/300
# 5/5 [==============================] - 0s 7ms/step - loss: 1.5488

# %%
model = load_model("bitcoin_8_2.h5")
error_pred = model.predict(x_train)
error_pred
# Out:
# 5/5 [==============================] - 0s 2ms/step
# array([[ -5.0116286 ],
#        [ -4.205816  ],
#        [ -3.8632216 ],
#        [ -3.9354537 ],
#        [ -2.8120987 ],
#        [ -1.8229654 ],
#        [ -4.223696  ],
#        [ -2.6877604 ],
#        [ -3.0746028 ],
#        [ -3.041722  ],
#        [ -4.202792  ],
#        [ -3.4222496 ],
#        [ -4.4773674 ],
#        [ -5.4092307 ],
#        [ -9.658636  ],
#        [ -9.973732  ],
#        [ -9.952898  ],
#        [ -9.513789  ],
#        [ -9.121442  ],
#        [ -9.157815  ],
#        [ -8.826379  ],
#        [ -8.30655   ],
#        [ -7.795366  ],
#        [ -7.8937564 ],
#        [ -7.3545566 ],
#        [ -7.1667767 ],
#        [ -8.616316  ],
#        [ -8.288847  ],
#        [ -4.9768376 ],
#        [ -3.6893184 ],
#        [ -3.2120144 ],
#        [ -1.7877432 ],
#        [ -2.2701998 ],
#        [ -1.490695  ],
#        [ -3.1045516 ],
#        [ -4.2743464 ],
#        [ -3.7337673 ],
#        [ -3.7923996 ],
#        [ -3.0763233 ],
#        [ -1.0339857 ],
#        [ -3.6798148 ],
#        [ -5.832176  ],
#        [ -6.095866  ],
#        [ -5.6807156 ],
#        [ -7.2756977 ],
#        [ -8.379851  ],
#        [ -7.5547566 ],
#        [ -8.511593  ],
#        [ -7.4836464 ],
#        [ -6.813653  ],
#        [ -6.70469   ],
#        [ -7.8061028 ],
#        [ -2.7193015 ],
#        [ -1.8317605 ],
#        [ -2.9098992 ],
#        [ -4.411801  ],
#        [ -6.9723554 ],
#        [ -6.335021  ],
#        [ -7.1921525 ],
#        [ -7.5105834 ],
#        [ -7.0742984 ],
#        [ -4.3264356 ],
#        [ -6.626413  ],
#        [ -7.0522323 ],
#        [ -6.828984  ],
#        [ -7.793987  ],
#        [ -6.1845627 ],
#        [ -6.2588716 ],
#        [ -4.8040004 ],
#        [ -4.557775  ],
#        [ -3.950203  ],
#        [ -3.530869  ],
#        [ -5.005761  ],
#        [ -4.91499   ],
#        [ -3.2326834 ],
#        [ -2.7779315 ],
#        [ -1.7684392 ],
#        [ -1.6516128 ],
#        [ -1.3161613 ],
#        [  1.9811932 ],
#        [  1.5004169 ],
#        [  0.644941  ],
#        [  0.38824314],
#        [ -0.31147367],
#        [  0.43938234],
#        [ -0.12155393],
#        [  0.30451566],
#        [  0.42665178],
#        [ -1.0224118 ],
#        [ -2.884633  ],
#        [ -3.4978514 ],
#        [ -4.352353  ],
#        [ -2.9681814 ],
#        [ -4.1687465 ],
#        [ -6.8806324 ],
#        [ -5.654776  ],
#        [ -4.8024244 ],
#        [ -5.8148103 ],
#        [ -5.223271  ],
#        [ -5.453617  ],
#        [ -6.052287  ],
#        [ -5.03451   ],
#        [ -4.2934127 ],
#        [ -4.5048633 ],
#        [ -5.4561825 ],
#        [ -6.113795  ],
#        [ -6.26557   ],
#        [ -6.2610106 ],
#        [ -5.4162145 ],
#        [ -7.466433  ],
#        [ -6.3906145 ],
#        [ -6.1791415 ],
#        [ -7.049914  ],
#        [ -7.838938  ],
#        [ -7.271359  ],
#        [ -7.3628187 ],
#        [ -7.9127975 ],
#        [ -6.2480445 ],
#        [ -8.571375  ],
#        [ -9.270238  ],
#        [-10.472791  ],
#        [-11.842541  ],
#        [-14.945985  ],
#        [-15.144853  ],
#        [-16.274998  ],
#        [-16.797392  ],
#        [-16.36764   ],
#        [-15.767182  ],
#        [-14.827205  ],
#        [-15.685314  ],
#        [-15.741837  ],
#        [-16.59237   ],
#        [-15.950369  ],
#        [-16.11114   ],
#        [-16.417423  ],
#        [-15.630513  ],
#        [-16.30362   ],
#        [-16.294125  ],
#        [-16.073984  ],
#        [-16.41516   ],
#        [-16.832458  ],
#        [-16.626873  ],
#        [-16.16297   ],
#        [-14.61866   ]], dtype=float32)

# %%
df_lstm = df_lstm.copy().head(len(error_pred))
df_lstm['Error Prediction'] = error_pred
df_lstm
# Out:
#              Actual    ARIMA    Error  Error Prediction
# Date
# 2022-01-06  43.4316  45.8331  -2.4015         -5.011629
# 2022-01-07  43.0979  45.8331  -2.7352         -4.205816
# 2022-01-08  41.5513  45.8331  -4.2818         -3.863222
# 2022-01-09  41.6812  45.8331  -4.1519         -3.935454
# 2022-01-10  41.8489  45.8331  -3.9842         -2.812099
# ...             ...      ...      ...               ...
# 2022-05-25  29.6487  45.8331 -16.1844        -16.415159
# 2022-05-26  29.5379  45.8331 -16.2952        -16.832458
# 2022-05-27  29.1940  45.8331 -16.6391        -16.626873
# 2022-05-28  28.6201  45.8331 -17.2130        -16.162970
# 2022-05-29  29.0271  45.8331 -16.8060        -14.618660
#
# [144 rows x 4 columns]

# %%
df_lstm['ARIMA_LSTM'] = df_lstm['ARIMA'] + df_lstm['Error Prediction']
df_lstm
# Out:
#              Actual    ARIMA    Error  Error Prediction  ARIMA_LSTM
# Date
# 2022-01-06  43.4316  45.8331  -2.4015         -5.011629   40.821471
# 2022-01-07  43.0979  45.8331  -2.7352         -4.205816   41.627284
# 2022-01-08  41.5513  45.8331  -4.2818         -3.863222   41.969878
# 2022-01-09  41.6812  45.8331  -4.1519         -3.935454   41.897646
# 2022-01-10  41.8489  45.8331  -3.9842         -2.812099   43.021001
# ...             ...      ...      ...               ...         ...
# 2022-05-25  29.6487  45.8331 -16.1844        -16.415159   29.417941
# 2022-05-26  29.5379  45.8331 -16.2952        -16.832458   29.000642
# 2022-05-27  29.1940  45.8331 -16.6391        -16.626873   29.206227
# 2022-05-28  28.6201  45.8331 -17.2130        -16.162970   29.670130
# 2022-05-29  29.0271  45.8331 -16.8060        -14.618660   31.214440
#
# [144 rows x 5 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(df_lstm['Actual'], 'blue', label='Actual data')
plt.plot(df_lstm['ARIMA_LSTM'], 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mape = mean_absolute_percentage_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
mse = mean_squared_error(df_lstm.Actual, df_lstm.ARIMA_LSTM)
rmse = np.sqrt(mse)
r2 = r2_score(df_lstm.Actual, df_lstm.ARIMA_LSTM)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 1.40
# MAPE: 3.55%
# MSE: 3.61
# RMSE: 1.90
# R2: 0.84

# %% [markdown]
# # Lấy 3 ngày cuối ra để dự báo

# %%
forecast = df_lstm['Error'].tail(3)
forecast
# Out:
# Date
# 2022-05-27   -16.6391
# 2022-05-28   -17.2130
# 2022-05-29   -16.8060
# Name: Error, dtype: float64

# %% [markdown]
# # Đưa về ma trận

# %%
dataX = []
for i in range(len(forecast)):
    a=forecast[i]
    dataX.append(a)
dataX = np.array(dataX).reshape(1,-1,1)
dataX
# Out:
# array([[[-16.6391],
#         [-17.213 ],
#         [-16.806 ]]])

# %%
y_forecast= model.predict(dataX).reshape(1,)
y_forecast
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([-16.626873], dtype=float32)

# %% [markdown]
# # So sánh kết quả dự đoán với giá trị thực

# %%
y_arima = df_pred.copy()
y_arima = y_arima.tail(4).head(1)
y_arima
# Out:
#              Actual    ARIMA   Error
# Date
# 2022-05-29  29.0271  45.8331 -16.806

# %%
y_arima['Final_LSTM'] = y_arima.ARIMA + y_forecast
y_arima
# Out:
#              Actual    ARIMA   Error  Final_LSTM
# Date
# 2022-05-29  29.0271  45.8331 -16.806   29.206227

# %% [markdown]
# # Ghi ra file csv

# %%
df.to_csv("btc_processed_data_8_2.csv")
df_scaled.to_csv("btc_scaled_data_8_2.csv")
df_pred.to_csv("btc_ARIMA-PRED_8_2.csv")
df_lstm.to_csv("btc_LSTM_PRED_8_2.csv")
y_arima.to_csv("btc_Forecast_8_2.csv")
