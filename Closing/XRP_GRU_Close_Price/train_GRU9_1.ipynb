# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình GRU

# %% [markdown]
# Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import GRUV2 as GRU

# %% [markdown]
# Nạp dữ liệu từ file csv

# %%
start = '01/06/2020'
end = '01/06/2022'
pre_day = 30
stock="xrp"
# df = investpy.get_crypto_historical_data(crypto=stock ,from_date=start, to_date=end)
df=pd.read_csv('xrp_train_9_1.csv')
df = pd.DataFrame(df)
df
# Out:
#            Date     Open     High      Low    Close      Volume Currency
# 0    2020-06-01  0.20254  0.21184  0.20132  0.21090  1662996864      USD
# 1    2020-06-02  0.21090  0.21452  0.19826  0.20317  2046863744      USD
# 2    2020-06-03  0.20316  0.20475  0.20104  0.20411  1226735360      USD
# 3    2020-06-04  0.20411  0.20713  0.20121  0.20438  1357705728      USD
# 4    2020-06-05  0.20438  0.20567  0.20174  0.20282  1165720704      USD
# ..          ...      ...      ...      ...      ...         ...      ...
# 653  2022-03-16  0.76586  0.79427  0.75816  0.79190   560469888      USD
# 654  2022-03-17  0.79204  0.80125  0.78330  0.79331   436895776      USD
# 655  2022-03-18  0.79370  0.80049  0.77704  0.79661   362681824      USD
# 656  2022-03-19  0.79652  0.82648  0.79181  0.81970   467541792      USD
# 657  2022-03-20  0.81958  0.82170  0.79651  0.80606   344777408      USD
#
# [658 rows x 7 columns]

# %% [markdown]
# Chuẩn hóa dữ liệu

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
# Đường Simple Moving Average (SMA)
# là đường trung bình động đơn giản được tính bằng trung bình cộng các mức giá đóng cửa trong một khoảng thời gian giao dịch nhất định.
# Vd MA_7 = Khoảng thời gian (7 ngày về sau tính cả ngày đang tính)
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv(f"{stock}_9_1_standardized.csv")
print(df)
# Out:
#            Date     Open     High      Low    Close      Volume Currency  \
# 20   2020-06-21  0.18793  0.18840  0.18577  0.18606   623938624      USD
# 21   2020-06-22  0.18606  0.19018  0.18584  0.18941  1066312000      USD
# 22   2020-06-23  0.18942  0.19042  0.18839  0.18886   793852224      USD
# 23   2020-06-24  0.18886  0.19010  0.18179  0.18351  1010395648      USD
# 24   2020-06-25  0.18352  0.18406  0.17897  0.18155   912398528      USD
# ..          ...      ...      ...      ...      ...         ...      ...
# 653  2022-03-16  0.76586  0.79427  0.75816  0.79190   560469888      USD
# 654  2022-03-17  0.79204  0.80125  0.78330  0.79331   436895776      USD
# 655  2022-03-18  0.79370  0.80049  0.77704  0.79661   362681824      USD
# 656  2022-03-19  0.79652  0.82648  0.79181  0.81970   467541792      USD
# 657  2022-03-20  0.81958  0.82170  0.79651  0.80606   344777408      USD
#
#          H-L      O-C     SMA_7    SMA_14    SMA_21      SD_7     SD_21
# 20   0.00263  0.00187  0.189860  0.192946  0.196841  0.002852  0.007476
# 21   0.00434 -0.00335  0.189431  0.191899  0.195818  0.002621  0.006904
# 22   0.00203  0.00056  0.188927  0.191008  0.195137  0.002273  0.006848
# 23   0.00831  0.00535  0.187546  0.189637  0.194156  0.002195  0.006973
# 24   0.00509  0.00197  0.186370  0.189149  0.193069  0.002892  0.007078
# ..       ...      ...       ...       ...       ...       ...       ...
# 653  0.03611 -0.02604  0.773831  0.754761  0.754179  0.022449  0.029368
# 654  0.01795 -0.00127  0.782004  0.757726  0.758813  0.015874  0.027335
# 655  0.02345 -0.00291  0.781074  0.763715  0.760115  0.014568  0.028485
# 656  0.03467 -0.02318  0.785910  0.768414  0.763413  0.020731  0.031190
# 657  0.02519  0.01352  0.792571  0.774224  0.767443  0.018134  0.030962
#
# [638 rows x 14 columns]

# %% [markdown]
# Scale Miền giá trị lại

# %%
# Process Data
pre_day = 30
scala_x = MinMaxScaler()
scala_y = MinMaxScaler()
cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))

# %%
x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
x_total=np.array(x_total)
y_total=np.array(y_total)

# %%
# Build Model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_total.shape[1], x_total.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_total, y_total, epochs=60, steps_per_epoch=40, use_multiprocessing=True)
model.save(f"{stock}91.h5")
print("Done Training Model")
# Out:
# Epoch 1/60
# 40/40 [==============================] - 9s 24ms/step - loss: 0.0239
# Epoch 2/60
# 40/40 [==============================] - 1s 25ms/step - loss: 0.0119
# Epoch 3/60
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0097
# Epoch 4/60
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0084
# Epoch 5/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0082
# Epoch 6/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0061
# Epoch 7/60
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0065
# Epoch 8/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0054
# Epoch 9/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0048
# Epoch 10/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0041
# Epoch 11/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0046
# Epoch 12/60
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0046
# Epoch 13/60
# 40/40 [==============================] - 1s 26ms/step - loss: 0.0034
# Epoch 14/60
# 40/40 [==============================] - 1s 27ms/step - loss: 0.0045
# Epoch 15/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0044
# Epoch 16/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0039
# Epoch 17/60
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 18/60
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0039
# Epoch 19/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0040
# Epoch 20/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0047
# Epoch 21/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0034
# Epoch 22/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0037
# Epoch 23/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0036
# Epoch 24/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0043
# Epoch 25/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0035
# Epoch 26/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0033
# Epoch 27/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0031
# Epoch 28/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0040
# Epoch 29/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0038
# Epoch 30/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0029
# Epoch 31/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0037
# Epoch 32/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0032
# Epoch 33/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0027
# Epoch 34/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0029
# Epoch 35/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0035
# Epoch 36/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0031
# Epoch 37/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0031
# Epoch 38/60
# 40/40 [==============================] - 1s 28ms/step - loss: 0.0030
# Epoch 39/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0030
# Epoch 40/60
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0038
# Epoch 41/60
# 40/40 [==============================] - 1s 29ms/step - loss: 0.0029
# Epoch 42/60
# 40/40 [==============================] - 1s 30ms/step - loss: 0.0033
# Epoch 43/60
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0026
# Epoch 44/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0036
# Epoch 45/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0029
# Epoch 46/60
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0026
# Epoch 47/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0032
# Epoch 48/60
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0030
# Epoch 49/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0030
# Epoch 50/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0027
# Epoch 51/60
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0029
# Epoch 52/60
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0025
# Epoch 53/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0029
# Epoch 54/60
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0037
# Epoch 55/60
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0026
# Epoch 56/60
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0029
# Epoch 57/60
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0032
# Epoch 58/60
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2400 batches). You may need to use the repeat() function when building your dataset.
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0032
# Done Training Model
