# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình GRU

# %% [markdown]
# Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import GRUV2 as GRU

# %% [markdown]
# Nạp dữ liệu từ file csv

# %%
start = '01/06/2020'
end = '01/06/2022'
pre_day = 30
stock="ethereum"
# df = investpy.get_crypto_historical_data(crypto=stock ,from_date=start, to_date=end)
df=pd.read_csv('ethereum_train_7_3.csv')
df = pd.DataFrame(df)
df
# Out:
#            Date     Open     High      Low    Close    Volume Currency
# 0    2020-06-01  0.23180  0.24981  0.23085  0.24797  11970598      USD
# 1    2020-06-02  0.24801  0.25321  0.22795  0.23794  12686011      USD
# 2    2020-06-03  0.23790  0.24476  0.23384  0.24452   8151002      USD
# 3    2020-06-04  0.24453  0.24641  0.23668  0.24337   8749785      USD
# 4    2020-06-05  0.24337  0.24750  0.23970  0.24023   7754761      USD
# ..          ...      ...      ...      ...      ...       ...      ...
# 507  2021-10-21  4.16051  4.36691  4.02948  4.05416   1140074      USD
# 508  2021-10-22  4.05389  4.16411  3.89640  3.97094    654771      USD
# 509  2021-10-23  3.97094  4.16933  3.93879  4.16885    487025      USD
# 510  2021-10-24  4.16880  4.18400  3.96584  4.08280    507629      USD
# 511  2021-10-25  4.08268  4.23476  4.06994  4.21992    481414      USD
#
# [512 rows x 7 columns]

# %% [markdown]
# Chuẩn hóa dữ liệu

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
# Đường Simple Moving Average (SMA)
# là đường trung bình động đơn giản được tính bằng trung bình cộng các mức giá đóng cửa trong một khoảng thời gian giao dịch nhất định.
# Vd MA_7 = Khoảng thời gian (7 ngày về sau tính cả ngày đang tính)
df[f'SMA_{ma_1}'] = df['Close'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Close'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Close'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Close'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Close'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv(f"{stock}7_3_standardized.csv")
print(df)
# Out:
#            Date     Open     High      Low    Close   Volume Currency  \
# 20   2020-06-21  0.22887  0.23118  0.22738  0.22813  4102533      USD
# 21   2020-06-22  0.22811  0.24639  0.22769  0.24325  7929329      USD
# 22   2020-06-23  0.24324  0.24477  0.24094  0.24320  5163349      USD
# 23   2020-06-24  0.24320  0.24923  0.23156  0.23475  9127950      USD
# 24   2020-06-25  0.23475  0.23529  0.22799  0.23256  6475813      USD
# ..          ...      ...      ...      ...      ...      ...      ...
# 507  2021-10-21  4.16051  4.36691  4.02948  4.05416  1140074      USD
# 508  2021-10-22  4.05389  4.16411  3.89640  3.97094   654771      USD
# 509  2021-10-23  3.97094  4.16933  3.93879  4.16885   487025      USD
# 510  2021-10-24  4.16880  4.18400  3.96584  4.08280   507629      USD
# 511  2021-10-25  4.08268  4.23476  4.06994  4.21992   481414      USD
#
#          H-L      O-C     SMA_7    SMA_14    SMA_21      SD_7     SD_21
# 20   0.00380  0.00074  0.231087  0.235277  0.237832  0.002701  0.006701
# 21   0.01870 -0.01514  0.232847  0.235068  0.237607  0.005323  0.006417
# 22   0.00383  0.00004  0.233967  0.235024  0.237858  0.006609  0.006532
# 23   0.01767  0.00845  0.234091  0.234093  0.237392  0.006615  0.006380
# 24   0.00730  0.00219  0.234266  0.234225  0.236878  0.006546  0.006309
# ..       ...      ...       ...       ...       ...       ...       ...
# 507  0.33743  0.10635  3.911193  3.739975  3.644603  0.143477  0.230747
# 508  0.26771  0.08295  3.926056  3.769369  3.676118  0.143513  0.227813
# 509  0.23054 -0.19791  3.974813  3.811844  3.713255  0.161338  0.241800
# 510  0.21816  0.08600  4.008717  3.859542  3.744943  0.154416  0.244669
# 511  0.16482 -0.13724  4.076191  3.907746  3.784801  0.120845  0.250841
#
# [492 rows x 14 columns]

# %% [markdown]
# Scale Miền giá trị lại

# %%
# Process Data
pre_day = 30
scala_x = MinMaxScaler()
scala_y = MinMaxScaler()
cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Close']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))
# scaled_data_x
scaled_data_y
# Out:
# array([[0.001768  ],
#        [0.00554908],
#        [0.00553658],
#        [0.00342348],
#        [0.00287582],
#        [0.00215311],
#        [0.        ],
#        [0.00100779],
#        [0.00170299],
#        [0.00114283],
#        [0.0024732 ],
#        [0.00134038],
#        [0.00101529],
#        [0.00202308],
#        [0.00173049],
#        [0.00512646],
#        [0.0045488 ],
#        [0.00648435],
#        [0.00524149],
#        [0.00505144],
#        [0.00453629],
#        [0.00542405],
#        [0.00466883],
#        [0.00486139],
#        [0.00439125],
#        [0.0031484 ],
#        [0.00292333],
#        [0.00367355],
#        [0.00448878],
#        [0.00376107],
#        [0.00611924],
#        [0.01055801],
#        [0.01357387],
#        [0.01457165],
#        [0.02107101],
#        [0.02252392],
#        [0.02519218],
#        [0.02398183],
#        [0.0241969 ],
#        [0.02846061],
#        [0.03137144],
#        [0.04153184],
#        [0.03776576],
#        [0.04119674],
#        [0.04215201],
#        [0.04494531],
#        [0.04345488],
#        [0.0396388 ],
#        [0.04393752],
#        [0.04230456],
#        [0.04362993],
#        [0.03949876],
#        [0.04152684],
#        [0.05082699],
#        [0.05425796],
#        [0.05279505],
#        [0.05315765],
#        [0.05238993],
#        [0.05028933],
#        [0.04660828],
#        [0.0487614 ],
#        [0.0417444 ],
#        [0.04363744],
#        [0.04237208],
#        [0.0466733 ],
#        [0.04054656],
#        [0.04123675],
#        [0.04052405],
#        [0.0435249 ],
#        [0.04444767],
#        [0.05196481],
#        [0.05322517],
#        [0.06370316],
#        [0.05452054],
#        [0.04023897],
#        [0.04123175],
#        [0.02847061],
#        [0.03311694],
#        [0.03275934],
#        [0.0291083 ],
#        [0.03251927],
#        [0.03672547],
#        [0.03817588],
#        [0.0417419 ],
#        [0.03617281],
#        [0.03892109],
#        [0.03574769],
#        [0.03596525],
#        [0.04198947],
#        [0.04079663],
#        [0.0410592 ],
#        [0.03752569],
#        [0.03006857],
#        [0.03075126],
#        [0.02472955],
#        [0.03203663],
#        [0.03265181],
#        [0.03330699],
#        [0.0340522 ],
#        [0.03326448],
#        [0.03470989],
#        [0.03459236],
#        [0.03301191],
#        [0.03116388],
#        [0.03114388],
#        [0.03292688],
#        [0.03306442],
#        [0.02989602],
#        [0.03011358],
#        [0.03245175],
#        [0.03606528],
#        [0.03728563],
#        [0.03829341],
#        [0.0414168 ],
#        [0.04005392],
#        [0.03953377],
#        [0.03910865],
#        [0.03603777],
#        [0.03690302],
#        [0.03919867],
#        [0.03954377],
#        [0.036833  ],
#        [0.04254713],
#        [0.04826125],
#        [0.04687836],
#        [0.0477286 ],
#        [0.04627069],
#        [0.04327483],
#        [0.40510295],
#        [0.42435344],
#        [0.4368495 ],
#        [0.47850888],
#        [0.4470099 ],
#        [0.4638522 ],
#        [0.47147187],
#        [0.47275223],
#        [0.43522404],
#        [0.46484748],
#        [0.46159906],
#        [0.47831882],
#        [0.48272758],
#        [0.47932411],
#        [0.51986566],
#        [0.55278254],
#        [0.57345343],
#        [0.55068695],
#        [0.52446697],
#        [0.50417119],
#        [0.48503073],
#        [0.52792046],
#        [0.53509   ],
#        [0.54516537],
#        [0.53671546],
#        [0.49885968],
#        [0.52400434],
#        [0.57817978],
#        [0.6112192 ],
#        [0.63154999],
#        [0.63425576],
#        [0.63811186],
#        [0.68109411],
#        [0.68251202],
#        [0.80230616],
#        [0.76663099],
#        [0.82566031],
#        [0.81734794],
#        [0.81527235],
#        [0.92138509],
#        [0.92555628],
#        [0.93197561],
#        [0.98696128],
#        [0.89793341],
#        [0.87488934],
#        [0.9638547 ],
#        [0.85539129],
#        [0.84050454],
#        [0.76487299],
#        [0.78934746],
#        [0.55381534],
#        [0.6393047 ],
#        [0.55317015],
#        [0.51778257],
#        [0.47020401],
#        [0.60660538],
#        [0.62118454],
#        [0.66608984],
#        [0.62888423],
#        [0.54846381],
#        [0.51389896],
#        [0.5414143 ],
#        [0.62202978],
#        [0.60332445],
#        [0.62143711],
#        [0.6582601 ],
#        [0.61653571],
#        [0.60215161],
#        [0.62332765],
#        [0.59306152],
#        [0.57256068],
#        [0.59646249],
#        [0.56238778],
#        [0.53274933],
#        [0.53700555],
#        [0.57196551],
#        [0.59027323],
#        [0.58085804],
#        [0.53670796],
#        [0.53779327],
#        [0.50226064],
#        [0.48660118],
#        [0.50584417],
#        [0.41764903],
#        [0.414018  ],
#        [0.43695703],
#        [0.44214601],
#        [0.39749078],
#        [0.40250471],
#        [0.43983035],
#        [0.46564021],
#        [0.4845506 ],
#        [0.5133413 ],
#        [0.47214706],
#        [0.48356782],
#        [0.5010528 ],
#        [0.52568982],
#        [0.49391577],
#        [0.52556479],
#        [0.52402685],
#        [0.47492535],
#        [0.48134468],
#        [0.47264971],
#        [0.47970922],
#        [0.45363679],
#        [0.43003756],
#        [0.4435214 ],
#        [0.42415839],
#        [0.4144031 ],
#        [0.41934951],
#        [0.41795912],
#        [0.39936632],
#        [0.39136404],
#        [0.44348389],
#        [0.45100854],
#        [0.4757731 ],
#        [0.48283511],
#        [0.49232281],
#        [0.50226064],
#        [0.51993818],
#        [0.5196606 ],
#        [0.54012143],
#        [0.56013214],
#        [0.57794721],
#        [0.58395893],
#        [0.59691512],
#        [0.57156039],
#        [0.62623598],
#        [0.65172324],
#        [0.66728268],
#        [0.73444432],
#        [0.69795142],
#        [0.73567717],
#        [0.73012058],
#        [0.73585972],
#        [0.70583866],
#        [0.77556354],
#        [0.76112442],
#        [0.77217257],
#        [0.73185608],
#        [0.6985791 ],
#        [0.69916176],
#        [0.74115123],
#        [0.76600581],
#        [0.75093902],
#        [0.75462507],
#        [0.77482833],
#        [0.7382604 ],
#        [0.75198682],
#        [0.71832472],
#        [0.76334755],
#        [0.75592544],
#        [0.75048889],
#        [0.75136664],
#        [0.80264875],
#        [0.9031749 ],
#        [0.89153659],
#        [0.92907229],
#        [0.91623863],
#        [0.93265581],
#        [0.92680164],
#        [0.80074321],
#        [0.81874334],
#        [0.80084074],
#        [0.74676533],
#        [0.76178461],
#        [0.79703215],
#        [0.76608333],
#        [0.80218112],
#        [0.84795167],
#        [0.83733114],
#        [0.79462397],
#        [0.80395663],
#        [0.77723651],
#        [0.68894385],
#        [0.63529606],
#        [0.7143836 ],
#        [0.73317395],
#        [0.67707047],
#        [0.67556504],
#        [0.71081508],
#        [0.6764878 ],
#        [0.64673932],
#        [0.65779747],
#        [0.6950806 ],
#        [0.77223759],
#        [0.79220328],
#        [0.7992978 ],
#        [0.79068535],
#        [0.82428492],
#        [0.83882657],
#        [0.84147482],
#        [0.83482793],
#        [0.83852398],
#        [0.79872014],
#        [0.8312369 ],
#        [0.81744297],
#        [0.84679634],
#        [0.89259189],
#        [0.91171984],
#        [0.90187954],
#        [0.90636081],
#        [0.88188634],
#        [0.91419054],
#        [0.98498822],
#        [0.95854819],
#        [0.93773726],
#        [0.98722886],
#        [0.96571023],
#        [1.        ]])

# %%
x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
x_total=np.array(x_total)
y_total=np.array(y_total)

# %% [markdown]
# Tách tập dữ liệu thành train và test

# %%
# Build Model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_total.shape[1], x_total.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_total, y_total, epochs=60, steps_per_epoch=40, use_multiprocessing=True)
model.save(f"{stock}73.h5")
print("Done Training Model")
# Out:
# Epoch 1/60
# 40/40 [==============================] - 14s 42ms/step - loss: 0.0302
# Epoch 2/60
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0102
# Epoch 3/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0092
# Epoch 4/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0126
# Epoch 5/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0073
# Epoch 6/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0076
# Epoch 7/60
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0052
# Epoch 8/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0064
# Epoch 9/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0077
# Epoch 10/60
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0054
# Epoch 11/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0046
# Epoch 12/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0060
# Epoch 13/60
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0051
# Epoch 14/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0052
# Epoch 15/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0047
# Epoch 16/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0041
# Epoch 17/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0037
# Epoch 18/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0050
# Epoch 19/60
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0045
# Epoch 20/60
# 40/40 [==============================] - 2s 50ms/step - loss: 0.0038
# Epoch 21/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0037
# Epoch 22/60
# 40/40 [==============================] - 2s 49ms/step - loss: 0.0040
# Epoch 23/60
# 40/40 [==============================] - 2s 50ms/step - loss: 0.0035
# Epoch 24/60
# 40/40 [==============================] - 2s 49ms/step - loss: 0.0041
# Epoch 25/60
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0045
# Epoch 26/60
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0042
# Epoch 27/60
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0036
# Epoch 28/60
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0031
# Epoch 29/60
# 40/40 [==============================] - 2s 53ms/step - loss: 0.0032
# Epoch 30/60
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0027
# Epoch 31/60
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0042
# Epoch 32/60
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0033
# Epoch 33/60
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0033
# Epoch 34/60
# 40/40 [==============================] - 2s 51ms/step - loss: 0.0028
# Epoch 35/60
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0036
# Epoch 36/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0041
# Epoch 37/60
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0031
# Epoch 38/60
# 40/40 [==============================] - 2s 38ms/step - loss: 0.0027
# Epoch 39/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0030
# Epoch 40/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0032
# Epoch 41/60
# 40/40 [==============================] - 2s 50ms/step - loss: 0.0037
# Epoch 42/60
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0028
# Epoch 43/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0029
# Epoch 44/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0045
# Epoch 45/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0029
# Epoch 46/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0024
# Epoch 47/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0033
# Epoch 48/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0031
# Epoch 49/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0029
# Epoch 50/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0036
# Epoch 51/60
# 40/40 [==============================] - 2s 48ms/step - loss: 0.0029
# Epoch 52/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0027
# Epoch 53/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0030
# Epoch 54/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0033
# Epoch 55/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0027
# Epoch 56/60
# 40/40 [==============================] - 2s 47ms/step - loss: 0.0030
# Epoch 57/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0026
# Epoch 58/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0029
# Epoch 59/60
# 20/40 [==============>...............] - ETA: 0s - loss: 0.0026WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2400 batches). You may need to use the repeat() function when building your dataset.
# 40/40 [==============================] - 2s 56ms/step - loss: 0.0026
# Done Training Model
