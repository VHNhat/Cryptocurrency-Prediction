# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình GRU

# %% [markdown]
# Thêm thư viện

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,Dropout
from keras.layers import GRUV2 as GRU

# %% [markdown]
# Nạp dữ liệu từ file csv

# %%
start = '01/06/2020'
end = '01/06/2022'
pre_day = 30
stock="bitcoin"
# df = investpy.get_crypto_historical_data(crypto=stock ,from_date=start, to_date=end)
df=pd.read_csv('bitcoin_train_8_2.csv')
df = pd.DataFrame(df)
df
# Out:
#            Date     Open     High      Low    Close   Volume Currency
# 0    2020-06-01   9.4545  10.3018   9.4297  10.1893   796676      USD
# 1    2020-06-02  10.1907  10.2073   9.3473   9.5276  1058556      USD
# 2    2020-06-03   9.5270   9.6672   9.4217   9.6672   558116      USD
# 3    2020-06-04   9.6672   9.8644   9.4909   9.7944   593664      USD
# 4    2020-06-05   9.7940   9.8461   9.6287   9.6312   527054      USD
# ..          ...      ...      ...      ...      ...      ...      ...
# 580  2022-01-02  47.7387  47.9449  46.7182  47.3118    27020      USD
# 581  2022-01-03  47.2939  47.5560  45.7040  46.4302    41062      USD
# 582  2022-01-04  46.4357  47.5054  45.6021  45.8373    55589      USD
# 583  2022-01-05  45.8331  47.0194  42.5351  43.4259    83744      USD
# 584  2022-01-06  43.4316  43.7723  42.4811  43.0975    63076      USD
#
# [585 rows x 7 columns]

# %% [markdown]
# Chuẩn hóa dữ liệu

# %%
df['H-L'] = df['High'] - df['Low']
df['O-C'] = df['Open'] - df['Close']
ma_1 = 7
ma_2 = 14
ma_3 = 21
# Đường Simple Moving Average (SMA)
# là đường trung bình động đơn giản được tính bằng trung bình cộng các mức giá đóng cửa trong một khoảng thời gian giao dịch nhất định.
# Vd MA_7 = Khoảng thời gian (7 ngày về sau tính cả ngày đang tính)
df[f'SMA_{ma_1}'] = df['Open'].rolling(window=ma_1).mean()
df[f'SMA_{ma_2}'] = df['Open'].rolling(window=ma_2).mean()
df[f'SMA_{ma_3}'] = df['Open'].rolling(window=ma_3).mean()

df[f'SD_{ma_1}'] = df['Open'].rolling(window=ma_1).std()
df[f'SD_{ma_3}'] = df['Open'].rolling(window=ma_3).std()
df.dropna(inplace=True)

df.to_csv(f"{stock}_8_2_standardized.csv")
print(df)
# Out:
#            Date     Open     High      Low    Close  Volume Currency     H-L  \
# 20   2020-06-21   9.3588   9.4112   9.2885   9.2964  335994      USD  0.1227
# 21   2020-06-22   9.2965   9.7519   9.2858   9.6837  523319      USD  0.4661
# 22   2020-06-23   9.6839   9.7156   9.5818   9.6246  375494      USD  0.1338
# 23   2020-06-24   9.6246   9.6674   9.2230   9.3020  515777      USD  0.4444
# 24   2020-06-25   9.3008   9.3273   9.0226   9.2475  524453      USD  0.3047
# ..          ...      ...      ...      ...      ...     ...      ...     ...
# 580  2022-01-02  47.7387  47.9449  46.7182  47.3118   27020      USD  1.2267
# 581  2022-01-03  47.2939  47.5560  45.7040  46.4302   41062      USD  1.8520
# 582  2022-01-04  46.4357  47.5054  45.6021  45.8373   55589      USD  1.9033
# 583  2022-01-05  45.8331  47.0194  42.5351  43.4259   83744      USD  4.4843
# 584  2022-01-06  43.4316  43.7723  42.4811  43.0975   63076      USD  1.2912
#
#         O-C      SMA_7     SMA_14     SMA_21      SD_7     SD_21
# 20   0.0624   9.403200   9.515150   9.578376  0.073248  0.224706
# 21  -0.3872   9.396200   9.483229   9.570852  0.081552  0.231601
# 22   0.0593   9.433100   9.476529   9.546719  0.136797  0.185623
# 23   0.3226   9.447529   9.466229   9.551367  0.152373  0.186325
# 24   0.0533   9.424129   9.424936   9.533919  0.161611  0.192005
# ..      ...        ...        ...        ...       ...       ...
# 580  0.4269  48.083657  48.549171  48.303562  1.895816  1.685884
# 581  0.8637  47.585129  48.591350  48.171086  1.480935  1.648542
# 582  0.5984  46.975457  48.558179  48.158033  0.599261  1.661722
# 583  2.4072  46.730414  48.339207  48.037410  0.672195  1.736129
# 584  0.3341  46.296257  47.970064  47.778124  1.426321  1.992238
#
# [565 rows x 14 columns]

# %% [markdown]
# Scale Miền giá trị lại

# %%
# Process Data
pre_day = 30
scala_x = MinMaxScaler()
scala_y = MinMaxScaler()
cols_x = ['H-L', 'O-C', f'SMA_{ma_1}', f'SMA_{ma_2}', f'SMA_{ma_3}', f'SD_{ma_1}', f'SD_{ma_3}']
cols_y = ['Open']
scaled_data_x = scala_x.fit_transform(df[cols_x].values.reshape(-1, len(cols_x)))
scaled_data_y = scala_y.fit_transform(df[cols_y].values.reshape(-1, len(cols_y)))
# scaled_data_x
scaled_data_y
# Out:
# array([[0.00598767],
#        [0.00492308],
#        [0.011543  ],
#        [0.01052968],
#        [0.00499656],
#        [0.00408576],
#        [0.0025991 ],
#        [0.        ],
#        [0.00195488],
#        [0.00303484],
#        [0.00217873],
#        [0.00378501],
#        [0.00130895],
#        [0.00100307],
#        [0.00215139],
#        [0.00123034],
#        [0.0056459 ],
#        [0.00423614],
#        [0.00720605],
#        [0.00394051],
#        [0.00474024],
#        [0.00385849],
#        [0.00499143],
#        [0.00401057],
#        [0.00419   ],
#        [0.00325186],
#        [0.00217019],
#        [0.00251878],
#        [0.00276314],
#        [0.00341249],
#        [0.00262986],
#        [0.00647639],
#        [0.0086329 ],
#        [0.01009564],
#        [0.00919852],
#        [0.01164724],
#        [0.01579452],
#        [0.03336791],
#        [0.03246737],
#        [0.03584055],
#        [0.03568164],
#        [0.03972639],
#        [0.04774753],
#        [0.03517583],
#        [0.03785695],
#        [0.03719051],
#        [0.04659238],
#        [0.04697003],
#        [0.04414195],
#        [0.04709477],
#        [0.04567133],
#        [0.04922736],
#        [0.04070382],
#        [0.04355412],
#        [0.04720926],
#        [0.0468675 ],
#        [0.04848061],
#        [0.04939141],
#        [0.05595665],
#        [0.05017062],
#        [0.04686579],
#        [0.04867542],
#        [0.04307565],
#        [0.04532957],
#        [0.04499635],
#        [0.04689826],
#        [0.03958455],
#        [0.04193246],
#        [0.03962898],
#        [0.04305173],
#        [0.04203157],
#        [0.04601309],
#        [0.04504078],
#        [0.04965798],
#        [0.04109343],
#        [0.01982731],
#        [0.02501525],
#        [0.01852007],
#        [0.02200946],
#        [0.02338505],
#        [0.01911132],
#        [0.02077741],
#        [0.02275108],
#        [0.02361232],
#        [0.02449236],
#        [0.02262975],
#        [0.02848242],
#        [0.03036211],
#        [0.03317994],
#        [0.03302956],
#        [0.03288773],
#        [0.03542702],
#        [0.03266388],
#        [0.02411129],
#        [0.02602687],
#        [0.02101322],
#        [0.02958802],
#        [0.02871653],
#        [0.02938297],
#        [0.03021174],
#        [0.02880881],
#        [0.03135664],
#        [0.85318941],
#        [0.76450052],
#        [0.78177316],
#        [0.82500773],
#        [0.8336731 ],
#        [0.81823401],
#        [0.82363556],
#        [0.81145859],
#        [0.76233888],
#        [0.68673606],
#        [0.69042196],
#        [0.70982206],
#        [0.7106628 ],
#        [0.70862931],
#        [0.6593148 ],
#        [0.65156877],
#        [0.68906174],
#        [0.70176503],
#        [0.64424482],
#        [0.67254953],
#        [0.68127129],
#        [0.65997611],
#        [0.63505143],
#        [0.64673797],
#        [0.64413545],
#        [0.64749668],
#        [0.68164893],
#        [0.67653789],
#        [0.71426496],
#        [0.7139608 ],
#        [0.70737163],
#        [0.71385827],
#        [0.7124878 ],
#        [0.65857489],
#        [0.64015906],
#        [0.65131074],
#        [0.63583235],
#        [0.66182675],
#        [0.65422597],
#        [0.63956097],
#        [0.62926369],
#        [0.58822665]])

# %%
x_total = []
y_total = []

for i in range(pre_day, len(df)):
    x_total.append(scaled_data_x[i-pre_day:i])
    y_total.append(scaled_data_y[i])
x_total=np.array(x_total)
y_total=np.array(y_total)

# %% [markdown]
# Tách tập dữ liệu thành train và test

# %%
# Build Model
model = Sequential()

model.add(GRU(units=60, return_sequences=True, input_shape=(x_total.shape[1], x_total.shape[2])))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60, return_sequences=True))
model.add(Dropout(0.2))
model.add(GRU(units=60))
model.add(Dropout(0.2))
model.add(Dense(units=len(cols_y)))

model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(x_total, y_total, epochs=60, steps_per_epoch=40, use_multiprocessing=True)
model.save(f"{stock}82.h5")
print("Done Training Model")
# Out:
# Epoch 1/60
# 40/40 [==============================] - 26s 56ms/step - loss: 0.0332
# Epoch 2/60
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0145
# Epoch 3/60
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0108
# Epoch 4/60
# 40/40 [==============================] - 2s 58ms/step - loss: 0.0092
# Epoch 5/60
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0073
# Epoch 6/60
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0090
# Epoch 7/60
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0073
# Epoch 8/60
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0058
# Epoch 9/60
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0054
# Epoch 10/60
# 40/40 [==============================] - 2s 60ms/step - loss: 0.0046
# Epoch 11/60
# 40/40 [==============================] - 3s 64ms/step - loss: 0.0042
# Epoch 12/60
# 40/40 [==============================] - 2s 62ms/step - loss: 0.0045
# Epoch 13/60
# 40/40 [==============================] - 2s 61ms/step - loss: 0.0043
# Epoch 14/60
# 40/40 [==============================] - 3s 66ms/step - loss: 0.0044
# Epoch 15/60
# 40/40 [==============================] - 3s 71ms/step - loss: 0.0037
# Epoch 16/60
# 40/40 [==============================] - 3s 68ms/step - loss: 0.0035
# Epoch 17/60
# 40/40 [==============================] - 3s 63ms/step - loss: 0.0044
# Epoch 18/60
# 40/40 [==============================] - 3s 68ms/step - loss: 0.0039
# Epoch 19/60
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0036
# Epoch 20/60
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0032
# Epoch 21/60
# 40/40 [==============================] - 3s 64ms/step - loss: 0.0027
# Epoch 22/60
# 40/40 [==============================] - 3s 63ms/step - loss: 0.0031
# Epoch 23/60
# 40/40 [==============================] - 3s 69ms/step - loss: 0.0030
# Epoch 24/60
# 40/40 [==============================] - 2s 54ms/step - loss: 0.0036
# Epoch 25/60
# 40/40 [==============================] - 2s 57ms/step - loss: 0.0030
# Epoch 26/60
# 40/40 [==============================] - 2s 59ms/step - loss: 0.0034
# Epoch 27/60
# 40/40 [==============================] - 2s 52ms/step - loss: 0.0029
# Epoch 28/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0025
# Epoch 29/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0025
# Epoch 30/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0025
# Epoch 31/60
# 40/40 [==============================] - 2s 46ms/step - loss: 0.0031
# Epoch 32/60
# 40/40 [==============================] - 2s 43ms/step - loss: 0.0025
# Epoch 33/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0028
# Epoch 34/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0024
# Epoch 35/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0026
# Epoch 36/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0022
# Epoch 37/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0026
# Epoch 38/60
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0027
# Epoch 39/60
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0027
# Epoch 40/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0026
# Epoch 41/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0025
# Epoch 42/60
# 40/40 [==============================] - 2s 41ms/step - loss: 0.0022
# Epoch 43/60
# 40/40 [==============================] - 2s 42ms/step - loss: 0.0024
# Epoch 44/60
# 40/40 [==============================] - 2s 45ms/step - loss: 0.0024
# Epoch 45/60
# 40/40 [==============================] - 2s 49ms/step - loss: 0.0023
# Epoch 46/60
# 40/40 [==============================] - 2s 44ms/step - loss: 0.0016
# Epoch 47/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 48/60
# 40/40 [==============================] - 2s 40ms/step - loss: 0.0018
# Epoch 49/60
# 40/40 [==============================] - 1s 36ms/step - loss: 0.0025
# Epoch 50/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0023
# Epoch 51/60
# 40/40 [==============================] - 1s 37ms/step - loss: 0.0019
# Epoch 52/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0019
# Epoch 53/60
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0022
# Epoch 54/60
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0016
# Epoch 55/60
# 40/40 [==============================] - 1s 35ms/step - loss: 0.0022
# Epoch 56/60
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0033
# Epoch 57/60
# 40/40 [==============================] - 1s 32ms/step - loss: 0.0022
# Epoch 58/60
# 40/40 [==============================] - 1s 31ms/step - loss: 0.0019
# Epoch 59/60
# 19/40 [=============>................] - ETA: 0s - loss: 0.0018WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2400 batches). You may need to use the repeat() function when building your dataset.
# 40/40 [==============================] - 1s 33ms/step - loss: 0.0018
# Done Training Model
